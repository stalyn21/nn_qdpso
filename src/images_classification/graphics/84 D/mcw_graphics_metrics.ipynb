# %% [markdown]
# # Metrics of th breast cancer dataset using different optimizers

# %%
import cv2
import mahotas
import numpy as np
import joblib as jb
import pickle as pk
import seaborn as sns
import matplotlib.pyplot as plt

from os import listdir
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import Isomap
from sklearn.model_selection import train_test_split
from collections import Counter

from sklearn.metrics import f1_score, recall_score, precision_score
from sklearn.metrics import confusion_matrix

from sklearn.neural_network import MLPClassifier
from neuralNetwork.perceptron_qpso import perceptron 
from neuralNetwork.perceptron_pso import perceptron_pso
from neuralNetwork.perceptron_pso_bound import perceptron_pso_bound

# %%
#----------------
#Global variables
#----------------

root_path = './dataset2/'
#train_path = 'seg_train/seg_train/'
#test_path = 'seg_test/seg_test/'
#pred_path = 'seg_pred/seg_pred/'

# Dataset classes: buildings, forest, glacier, mountain, sea, street
data_clases = np.array(['cloudy', 
						'rain', 
						'shine', 
						'sunrise'])
IMG_HEIGHT = 150
IMG_WIDTH = 150

#---------------------------------
# Extract Global features
#---------------------------------
bins = 4 

# feature-descriptor-1: Hu Moments
def fd_hu_moments(image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    feature = cv2.HuMoments(cv2.moments(image)).flatten()
    return feature

# feature-descriptor-2: Haralick Texture
def fd_haralick(image):
    # convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # compute the haralick texture feature vector
    haralick = mahotas.features.haralick(gray).mean(axis=0)
    # return the result
    return haralick

# feature-descriptor-3: Color Histogram
def fd_histogram(image, mask=None):
    # convert the image to HSV color-space
    image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    # compute the color histogram
    hist  = cv2.calcHist([image], [0, 1, 2], None, [bins, bins, bins], [0, 256, 0, 256, 0, 256])
    # normalize the histogram
    cv2.normalize(hist, hist)
    # return the histogram
    return hist.flatten()

#---------------------------------
# prepare training and testing set
#---------------------------------

X_train_aux = []
y_train_aux = []

for c in range(len(data_clases)):
	for filename in listdir(root_path + data_clases[c] + '/'):
		# load image
		img_data = cv2.imread(root_path + data_clases[c] + '/' + filename) 
		img_data = cv2.resize(img_data, (IMG_HEIGHT, IMG_WIDTH))
        # Global Feature extraction
		fv_hu_moments = fd_hu_moments(img_data)
		#print(fv_hu_moments.shape)
		fv_haralick = fd_haralick(img_data)
		#print(fv_haralick.shape)        
		fv_histogram  = fd_histogram(img_data)
		#print(fv_histogram.shape)
		# Concatenate global features
		global_feature = np.hstack([fv_histogram, fv_haralick, fv_hu_moments])
		X_train_aux.append(global_feature)
		y_train_aux.append(c)
		print('> loaded %s %s' % (filename, img_data.shape))
		print('> global features %s %s' % (filename, global_feature.shape))

# convert to array
X_train_aux = np.array(X_train_aux)
y_train_aux = np.array(y_train_aux)

# normalize data
#X_train_aux = X_train_aux / 255

print('X_train shape: ', X_train_aux.shape)
print('y_train shape: ', y_train_aux.shape)
# Out:
# > loaded cloudy1.jpg (150, 150, 3)
# > global features cloudy1.jpg (84,)
# > loaded cloudy10.jpg (150, 150, 3)
# > global features cloudy10.jpg (84,)
# > loaded cloudy100.jpg (150, 150, 3)
# > global features cloudy100.jpg (84,)
# > loaded cloudy101.jpg (150, 150, 3)
# > global features cloudy101.jpg (84,)
# > loaded cloudy102.jpg (150, 150, 3)
# > global features cloudy102.jpg (84,)
# > loaded cloudy103.jpg (150, 150, 3)
# > global features cloudy103.jpg (84,)
# > loaded cloudy104.jpg (150, 150, 3)
# > global features cloudy104.jpg (84,)
# > loaded cloudy105.jpg (150, 150, 3)
# > global features cloudy105.jpg (84,)
# > loaded cloudy106.jpg (150, 150, 3)
# > global features cloudy106.jpg (84,)
# > loaded cloudy107.jpg (150, 150, 3)
# > global features cloudy107.jpg (84,)
# > loaded cloudy108.jpg (150, 150, 3)
# > global features cloudy108.jpg (84,)
# > loaded cloudy109.jpg (150, 150, 3)
# > global features cloudy109.jpg (84,)
# > loaded cloudy11.jpg (150, 150, 3)
# > global features cloudy11.jpg (84,)
# > loaded cloudy110.jpg (150, 150, 3)
# > global features cloudy110.jpg (84,)
# > loaded cloudy111.jpg (150, 150, 3)
# > global features cloudy111.jpg (84,)
# > loaded cloudy112.jpg (150, 150, 3)
# > global features cloudy112.jpg (84,)
# > loaded cloudy113.jpg (150, 150, 3)
# > global features cloudy113.jpg (84,)
# > loaded cloudy114.jpg (150, 150, 3)
# > global features cloudy114.jpg (84,)
# > loaded cloudy115.jpg (150, 150, 3)
# > global features cloudy115.jpg (84,)
# > loaded cloudy116.jpg (150, 150, 3)
# > global features cloudy116.jpg (84,)
# > loaded cloudy117.jpg (150, 150, 3)
# > global features cloudy117.jpg (84,)
# > loaded cloudy118.jpg (150, 150, 3)
# > global features cloudy118.jpg (84,)
# > loaded cloudy119.jpg (150, 150, 3)
# > global features cloudy119.jpg (84,)
# > loaded cloudy12.jpg (150, 150, 3)
# > global features cloudy12.jpg (84,)
# > loaded cloudy120.jpg (150, 150, 3)
# > global features cloudy120.jpg (84,)
# > loaded cloudy121.jpg (150, 150, 3)
# > global features cloudy121.jpg (84,)
# > loaded cloudy122.jpg (150, 150, 3)
# > global features cloudy122.jpg (84,)
# > loaded cloudy123.jpg (150, 150, 3)
# > global features cloudy123.jpg (84,)
# > loaded cloudy124.jpg (150, 150, 3)
# > global features cloudy124.jpg (84,)
# > loaded cloudy125.jpg (150, 150, 3)
# > global features cloudy125.jpg (84,)
# > loaded cloudy126.jpg (150, 150, 3)
# > global features cloudy126.jpg (84,)
# > loaded cloudy127.jpg (150, 150, 3)
# > global features cloudy127.jpg (84,)
# > loaded cloudy128.jpg (150, 150, 3)
# > global features cloudy128.jpg (84,)
# > loaded cloudy129.jpg (150, 150, 3)
# > global features cloudy129.jpg (84,)
# > loaded cloudy13.jpg (150, 150, 3)
# > global features cloudy13.jpg (84,)
# > loaded cloudy130.jpg (150, 150, 3)
# > global features cloudy130.jpg (84,)
# > loaded cloudy131.jpg (150, 150, 3)
# > global features cloudy131.jpg (84,)
# > loaded cloudy132.jpg (150, 150, 3)
# > global features cloudy132.jpg (84,)
# > loaded cloudy133.jpg (150, 150, 3)
# > global features cloudy133.jpg (84,)
# > loaded cloudy134.jpg (150, 150, 3)
# > global features cloudy134.jpg (84,)
# > loaded cloudy135.jpg (150, 150, 3)
# > global features cloudy135.jpg (84,)
# > loaded cloudy136.jpg (150, 150, 3)
# > global features cloudy136.jpg (84,)
# > loaded cloudy137.jpg (150, 150, 3)
# > global features cloudy137.jpg (84,)
# > loaded cloudy138.jpg (150, 150, 3)
# > global features cloudy138.jpg (84,)
# > loaded cloudy139.jpg (150, 150, 3)
# > global features cloudy139.jpg (84,)
# > loaded cloudy14.jpg (150, 150, 3)
# > global features cloudy14.jpg (84,)
# > loaded cloudy140.jpg (150, 150, 3)
# > global features cloudy140.jpg (84,)
# > loaded cloudy141.jpg (150, 150, 3)
# > global features cloudy141.jpg (84,)
# > loaded cloudy142.jpg (150, 150, 3)
# > global features cloudy142.jpg (84,)
# > loaded cloudy143.jpg (150, 150, 3)
# > global features cloudy143.jpg (84,)
# > loaded cloudy144.jpg (150, 150, 3)
# > global features cloudy144.jpg (84,)
# > loaded cloudy145.jpg (150, 150, 3)
# > global features cloudy145.jpg (84,)
# > loaded cloudy146.jpg (150, 150, 3)
# > global features cloudy146.jpg (84,)
# > loaded cloudy147.jpg (150, 150, 3)
# > global features cloudy147.jpg (84,)
# > loaded cloudy148.jpg (150, 150, 3)
# > global features cloudy148.jpg (84,)
# > loaded cloudy149.jpg (150, 150, 3)
# > global features cloudy149.jpg (84,)
# > loaded cloudy15.jpg (150, 150, 3)
# > global features cloudy15.jpg (84,)
# > loaded cloudy150.jpg (150, 150, 3)
# > global features cloudy150.jpg (84,)
# > loaded cloudy151.jpg (150, 150, 3)
# > global features cloudy151.jpg (84,)
# > loaded cloudy152.jpg (150, 150, 3)
# > global features cloudy152.jpg (84,)
# > loaded cloudy153.jpg (150, 150, 3)
# > global features cloudy153.jpg (84,)
# > loaded cloudy154.jpg (150, 150, 3)
# > global features cloudy154.jpg (84,)
# > loaded cloudy155.jpg (150, 150, 3)
# > global features cloudy155.jpg (84,)
# > loaded cloudy156.jpg (150, 150, 3)
# > global features cloudy156.jpg (84,)
# > loaded cloudy157.jpg (150, 150, 3)
# > global features cloudy157.jpg (84,)
# > loaded cloudy158.jpg (150, 150, 3)
# > global features cloudy158.jpg (84,)
# > loaded cloudy159.jpg (150, 150, 3)
# > global features cloudy159.jpg (84,)
# > loaded cloudy16.jpg (150, 150, 3)
# > global features cloudy16.jpg (84,)
# > loaded cloudy160.jpg (150, 150, 3)
# > global features cloudy160.jpg (84,)
# > loaded cloudy161.jpg (150, 150, 3)
# > global features cloudy161.jpg (84,)
# > loaded cloudy162.jpg (150, 150, 3)
# > global features cloudy162.jpg (84,)
# > loaded cloudy163.jpg (150, 150, 3)
# > global features cloudy163.jpg (84,)
# > loaded cloudy164.jpg (150, 150, 3)
# > global features cloudy164.jpg (84,)
# > loaded cloudy165.jpg (150, 150, 3)
# > global features cloudy165.jpg (84,)
# > loaded cloudy166.jpg (150, 150, 3)
# > global features cloudy166.jpg (84,)
# > loaded cloudy167.jpg (150, 150, 3)
# > global features cloudy167.jpg (84,)
# > loaded cloudy168.jpg (150, 150, 3)
# > global features cloudy168.jpg (84,)
# > loaded cloudy169.jpg (150, 150, 3)
# > global features cloudy169.jpg (84,)
# > loaded cloudy17.jpg (150, 150, 3)
# > global features cloudy17.jpg (84,)
# > loaded cloudy170.jpg (150, 150, 3)
# > global features cloudy170.jpg (84,)
# > loaded cloudy171.jpg (150, 150, 3)
# > global features cloudy171.jpg (84,)
# > loaded cloudy172.jpg (150, 150, 3)
# > global features cloudy172.jpg (84,)
# > loaded cloudy173.jpg (150, 150, 3)
# > global features cloudy173.jpg (84,)
# > loaded cloudy174.jpg (150, 150, 3)
# > global features cloudy174.jpg (84,)
# > loaded cloudy175.jpg (150, 150, 3)
# > global features cloudy175.jpg (84,)
# > loaded cloudy176.jpg (150, 150, 3)
# > global features cloudy176.jpg (84,)
# > loaded cloudy177.jpg (150, 150, 3)
# > global features cloudy177.jpg (84,)
# > loaded cloudy178.jpg (150, 150, 3)
# > global features cloudy178.jpg (84,)
# > loaded cloudy179.jpg (150, 150, 3)
# > global features cloudy179.jpg (84,)
# > loaded cloudy18.jpg (150, 150, 3)
# > global features cloudy18.jpg (84,)
# > loaded cloudy180.jpg (150, 150, 3)
# > global features cloudy180.jpg (84,)
# > loaded cloudy181.jpg (150, 150, 3)
# > global features cloudy181.jpg (84,)
# > loaded cloudy182.jpg (150, 150, 3)
# > global features cloudy182.jpg (84,)
# > loaded cloudy183.jpg (150, 150, 3)
# > global features cloudy183.jpg (84,)
# > loaded cloudy184.jpg (150, 150, 3)
# > global features cloudy184.jpg (84,)
# > loaded cloudy185.jpg (150, 150, 3)
# > global features cloudy185.jpg (84,)
# > loaded cloudy186.jpg (150, 150, 3)
# > global features cloudy186.jpg (84,)
# > loaded cloudy187.jpg (150, 150, 3)
# > global features cloudy187.jpg (84,)
# > loaded cloudy188.jpg (150, 150, 3)
# > global features cloudy188.jpg (84,)
# > loaded cloudy189.jpg (150, 150, 3)
# > global features cloudy189.jpg (84,)
# > loaded cloudy19.jpg (150, 150, 3)
# > global features cloudy19.jpg (84,)
# > loaded cloudy190.jpg (150, 150, 3)
# > global features cloudy190.jpg (84,)
# > loaded cloudy191.jpg (150, 150, 3)
# > global features cloudy191.jpg (84,)
# > loaded cloudy192.jpg (150, 150, 3)
# > global features cloudy192.jpg (84,)
# > loaded cloudy193.jpg (150, 150, 3)
# > global features cloudy193.jpg (84,)
# > loaded cloudy194.jpg (150, 150, 3)
# > global features cloudy194.jpg (84,)
# > loaded cloudy195.jpg (150, 150, 3)
# > global features cloudy195.jpg (84,)
# > loaded cloudy196.jpg (150, 150, 3)
# > global features cloudy196.jpg (84,)
# > loaded cloudy197.jpg (150, 150, 3)
# > global features cloudy197.jpg (84,)
# > loaded cloudy198.jpg (150, 150, 3)
# > global features cloudy198.jpg (84,)
# > loaded cloudy199.jpg (150, 150, 3)
# > global features cloudy199.jpg (84,)
# > loaded cloudy2.jpg (150, 150, 3)
# > global features cloudy2.jpg (84,)
# > loaded cloudy20.jpg (150, 150, 3)
# > global features cloudy20.jpg (84,)
# > loaded cloudy200.jpg (150, 150, 3)
# > global features cloudy200.jpg (84,)
# > loaded cloudy201.jpg (150, 150, 3)
# > global features cloudy201.jpg (84,)
# > loaded cloudy202.jpg (150, 150, 3)
# > global features cloudy202.jpg (84,)
# > loaded cloudy203.jpg (150, 150, 3)
# > global features cloudy203.jpg (84,)
# > loaded cloudy204.jpg (150, 150, 3)
# > global features cloudy204.jpg (84,)
# > loaded cloudy205.jpg (150, 150, 3)
# > global features cloudy205.jpg (84,)
# > loaded cloudy206.jpg (150, 150, 3)
# > global features cloudy206.jpg (84,)
# > loaded cloudy207.jpg (150, 150, 3)
# > global features cloudy207.jpg (84,)
# > loaded cloudy208.jpg (150, 150, 3)
# > global features cloudy208.jpg (84,)
# > loaded cloudy209.jpg (150, 150, 3)
# > global features cloudy209.jpg (84,)
# > loaded cloudy21.jpg (150, 150, 3)
# > global features cloudy21.jpg (84,)
# > loaded cloudy210.jpg (150, 150, 3)
# > global features cloudy210.jpg (84,)
# > loaded cloudy211.jpg (150, 150, 3)
# > global features cloudy211.jpg (84,)
# > loaded cloudy212.jpg (150, 150, 3)
# > global features cloudy212.jpg (84,)
# > loaded cloudy213.jpg (150, 150, 3)
# > global features cloudy213.jpg (84,)
# > loaded cloudy214.jpg (150, 150, 3)
# > global features cloudy214.jpg (84,)
# > loaded cloudy215.jpg (150, 150, 3)
# > global features cloudy215.jpg (84,)
# > loaded cloudy216.jpg (150, 150, 3)
# > global features cloudy216.jpg (84,)
# > loaded cloudy217.jpg (150, 150, 3)
# > global features cloudy217.jpg (84,)
# > loaded cloudy218.jpg (150, 150, 3)
# > global features cloudy218.jpg (84,)
# > loaded cloudy219.jpg (150, 150, 3)
# > global features cloudy219.jpg (84,)
# > loaded cloudy22.jpg (150, 150, 3)
# > global features cloudy22.jpg (84,)
# > loaded cloudy220.jpg (150, 150, 3)
# > global features cloudy220.jpg (84,)
# > loaded cloudy221.jpg (150, 150, 3)
# > global features cloudy221.jpg (84,)
# > loaded cloudy222.jpg (150, 150, 3)
# > global features cloudy222.jpg (84,)
# > loaded cloudy223.jpg (150, 150, 3)
# > global features cloudy223.jpg (84,)
# > loaded cloudy224.jpg (150, 150, 3)
# > global features cloudy224.jpg (84,)
# > loaded cloudy225.jpg (150, 150, 3)
# > global features cloudy225.jpg (84,)
# > loaded cloudy226.jpg (150, 150, 3)
# > global features cloudy226.jpg (84,)
# > loaded cloudy227.jpg (150, 150, 3)
# > global features cloudy227.jpg (84,)
# > loaded cloudy228.jpg (150, 150, 3)
# > global features cloudy228.jpg (84,)
# > loaded cloudy229.jpg (150, 150, 3)
# > global features cloudy229.jpg (84,)
# > loaded cloudy23.jpg (150, 150, 3)
# > global features cloudy23.jpg (84,)
# > loaded cloudy230.jpg (150, 150, 3)
# > global features cloudy230.jpg (84,)
# > loaded cloudy231.jpg (150, 150, 3)
# > global features cloudy231.jpg (84,)
# > loaded cloudy232.jpg (150, 150, 3)
# > global features cloudy232.jpg (84,)
# > loaded cloudy233.jpg (150, 150, 3)
# > global features cloudy233.jpg (84,)
# > loaded cloudy234.jpg (150, 150, 3)
# > global features cloudy234.jpg (84,)
# > loaded cloudy235.jpg (150, 150, 3)
# > global features cloudy235.jpg (84,)
# > loaded cloudy236.jpg (150, 150, 3)
# > global features cloudy236.jpg (84,)
# > loaded cloudy237.jpg (150, 150, 3)
# > global features cloudy237.jpg (84,)
# > loaded cloudy238.jpg (150, 150, 3)
# > global features cloudy238.jpg (84,)
# > loaded cloudy239.jpg (150, 150, 3)
# > global features cloudy239.jpg (84,)
# > loaded cloudy24.jpg (150, 150, 3)
# > global features cloudy24.jpg (84,)
# > loaded cloudy240.jpg (150, 150, 3)
# > global features cloudy240.jpg (84,)
# > loaded cloudy241.jpg (150, 150, 3)
# > global features cloudy241.jpg (84,)
# > loaded cloudy242.jpg (150, 150, 3)
# > global features cloudy242.jpg (84,)
# > loaded cloudy243.jpg (150, 150, 3)
# > global features cloudy243.jpg (84,)
# > loaded cloudy244.jpg (150, 150, 3)
# > global features cloudy244.jpg (84,)
# > loaded cloudy245.jpg (150, 150, 3)
# > global features cloudy245.jpg (84,)
# > loaded cloudy246.jpg (150, 150, 3)
# > global features cloudy246.jpg (84,)
# > loaded cloudy247.jpg (150, 150, 3)
# > global features cloudy247.jpg (84,)
# > loaded cloudy248.jpg (150, 150, 3)
# > global features cloudy248.jpg (84,)
# > loaded cloudy249.jpg (150, 150, 3)
# > global features cloudy249.jpg (84,)
# > loaded cloudy25.jpg (150, 150, 3)
# > global features cloudy25.jpg (84,)
# > loaded cloudy250.jpg (150, 150, 3)
# > global features cloudy250.jpg (84,)
# > loaded cloudy251.jpg (150, 150, 3)
# > global features cloudy251.jpg (84,)
# > loaded cloudy252.jpg (150, 150, 3)
# > global features cloudy252.jpg (84,)
# > loaded cloudy253.jpg (150, 150, 3)
# > global features cloudy253.jpg (84,)
# > loaded cloudy254.jpg (150, 150, 3)
# > global features cloudy254.jpg (84,)
# > loaded cloudy255.jpg (150, 150, 3)
# > global features cloudy255.jpg (84,)
# > loaded cloudy256.jpg (150, 150, 3)
# > global features cloudy256.jpg (84,)
# > loaded cloudy257.jpg (150, 150, 3)
# > global features cloudy257.jpg (84,)
# > loaded cloudy258.jpg (150, 150, 3)
# > global features cloudy258.jpg (84,)
# > loaded cloudy259.jpg (150, 150, 3)
# > global features cloudy259.jpg (84,)
# > loaded cloudy26.jpg (150, 150, 3)
# > global features cloudy26.jpg (84,)
# > loaded cloudy260.jpg (150, 150, 3)
# > global features cloudy260.jpg (84,)
# > loaded cloudy261.jpg (150, 150, 3)
# > global features cloudy261.jpg (84,)
# > loaded cloudy262.jpg (150, 150, 3)
# > global features cloudy262.jpg (84,)
# > loaded cloudy263.jpg (150, 150, 3)
# > global features cloudy263.jpg (84,)
# > loaded cloudy264.jpg (150, 150, 3)
# > global features cloudy264.jpg (84,)
# > loaded cloudy265.jpg (150, 150, 3)
# > global features cloudy265.jpg (84,)
# > loaded cloudy266.jpg (150, 150, 3)
# > global features cloudy266.jpg (84,)
# > loaded cloudy267.jpg (150, 150, 3)
# > global features cloudy267.jpg (84,)
# > loaded cloudy268.jpg (150, 150, 3)
# > global features cloudy268.jpg (84,)
# > loaded cloudy269.jpg (150, 150, 3)
# > global features cloudy269.jpg (84,)
# > loaded cloudy27.jpg (150, 150, 3)
# > global features cloudy27.jpg (84,)
# > loaded cloudy270.jpg (150, 150, 3)
# > global features cloudy270.jpg (84,)
# > loaded cloudy271.jpg (150, 150, 3)
# > global features cloudy271.jpg (84,)
# > loaded cloudy272.jpg (150, 150, 3)
# > global features cloudy272.jpg (84,)
# > loaded cloudy273.jpg (150, 150, 3)
# > global features cloudy273.jpg (84,)
# > loaded cloudy274.jpg (150, 150, 3)
# > global features cloudy274.jpg (84,)
# > loaded cloudy275.jpg (150, 150, 3)
# > global features cloudy275.jpg (84,)
# > loaded cloudy276.jpg (150, 150, 3)
# > global features cloudy276.jpg (84,)
# > loaded cloudy277.jpg (150, 150, 3)
# > global features cloudy277.jpg (84,)
# > loaded cloudy278.jpg (150, 150, 3)
# > global features cloudy278.jpg (84,)
# > loaded cloudy279.jpg (150, 150, 3)
# > global features cloudy279.jpg (84,)
# > loaded cloudy28.jpg (150, 150, 3)
# > global features cloudy28.jpg (84,)
# > loaded cloudy280.jpg (150, 150, 3)
# > global features cloudy280.jpg (84,)
# > loaded cloudy281.jpg (150, 150, 3)
# > global features cloudy281.jpg (84,)
# > loaded cloudy282.jpg (150, 150, 3)
# > global features cloudy282.jpg (84,)
# > loaded cloudy283.jpg (150, 150, 3)
# > global features cloudy283.jpg (84,)
# > loaded cloudy284.jpg (150, 150, 3)
# > global features cloudy284.jpg (84,)
# > loaded cloudy285.jpg (150, 150, 3)
# > global features cloudy285.jpg (84,)
# > loaded cloudy286.jpg (150, 150, 3)
# > global features cloudy286.jpg (84,)
# > loaded cloudy287.jpg (150, 150, 3)
# > global features cloudy287.jpg (84,)
# > loaded cloudy288.jpg (150, 150, 3)
# > global features cloudy288.jpg (84,)
# > loaded cloudy289.jpg (150, 150, 3)
# > global features cloudy289.jpg (84,)
# > loaded cloudy29.jpg (150, 150, 3)
# > global features cloudy29.jpg (84,)
# > loaded cloudy290.jpg (150, 150, 3)
# > global features cloudy290.jpg (84,)
# > loaded cloudy291.jpg (150, 150, 3)
# > global features cloudy291.jpg (84,)
# > loaded cloudy292.jpg (150, 150, 3)
# > global features cloudy292.jpg (84,)
# > loaded cloudy293.jpg (150, 150, 3)
# > global features cloudy293.jpg (84,)
# > loaded cloudy294.jpg (150, 150, 3)
# > global features cloudy294.jpg (84,)
# > loaded cloudy295.jpg (150, 150, 3)
# > global features cloudy295.jpg (84,)
# > loaded cloudy296.jpg (150, 150, 3)
# > global features cloudy296.jpg (84,)
# > loaded cloudy297.jpg (150, 150, 3)
# > global features cloudy297.jpg (84,)
# > loaded cloudy298.jpg (150, 150, 3)
# > global features cloudy298.jpg (84,)
# > loaded cloudy299.jpg (150, 150, 3)
# > global features cloudy299.jpg (84,)
# > loaded cloudy3.jpg (150, 150, 3)
# > global features cloudy3.jpg (84,)
# > loaded cloudy30.jpg (150, 150, 3)
# > global features cloudy30.jpg (84,)
# > loaded cloudy300.jpg (150, 150, 3)
# > global features cloudy300.jpg (84,)
# > loaded cloudy31.jpg (150, 150, 3)
# > global features cloudy31.jpg (84,)
# > loaded cloudy32.jpg (150, 150, 3)
# > global features cloudy32.jpg (84,)
# > loaded cloudy33.jpg (150, 150, 3)
# > global features cloudy33.jpg (84,)
# > loaded cloudy34.jpg (150, 150, 3)
# > global features cloudy34.jpg (84,)
# > loaded cloudy35.jpg (150, 150, 3)
# > global features cloudy35.jpg (84,)
# > loaded cloudy36.jpg (150, 150, 3)
# > global features cloudy36.jpg (84,)
# > loaded cloudy37.jpg (150, 150, 3)
# > global features cloudy37.jpg (84,)
# > loaded cloudy38.jpg (150, 150, 3)
# > global features cloudy38.jpg (84,)
# > loaded cloudy39.jpg (150, 150, 3)
# > global features cloudy39.jpg (84,)
# > loaded cloudy4.jpg (150, 150, 3)
# > global features cloudy4.jpg (84,)
# > loaded cloudy40.jpg (150, 150, 3)
# > global features cloudy40.jpg (84,)
# > loaded cloudy41.jpg (150, 150, 3)
# > global features cloudy41.jpg (84,)
# > loaded cloudy42.jpg (150, 150, 3)
# > global features cloudy42.jpg (84,)
# > loaded cloudy43.jpg (150, 150, 3)
# > global features cloudy43.jpg (84,)
# > loaded cloudy44.jpg (150, 150, 3)
# > global features cloudy44.jpg (84,)
# > loaded cloudy45.jpg (150, 150, 3)
# > global features cloudy45.jpg (84,)
# > loaded cloudy46.jpg (150, 150, 3)
# > global features cloudy46.jpg (84,)
# > loaded cloudy47.jpg (150, 150, 3)
# > global features cloudy47.jpg (84,)
# > loaded cloudy48.jpg (150, 150, 3)
# > global features cloudy48.jpg (84,)
# > loaded cloudy49.jpg (150, 150, 3)
# > global features cloudy49.jpg (84,)
# > loaded cloudy5.jpg (150, 150, 3)
# > global features cloudy5.jpg (84,)
# > loaded cloudy50.jpg (150, 150, 3)
# > global features cloudy50.jpg (84,)
# > loaded cloudy51.jpg (150, 150, 3)
# > global features cloudy51.jpg (84,)
# > loaded cloudy52.jpg (150, 150, 3)
# > global features cloudy52.jpg (84,)
# > loaded cloudy53.jpg (150, 150, 3)
# > global features cloudy53.jpg (84,)
# > loaded cloudy54.jpg (150, 150, 3)
# > global features cloudy54.jpg (84,)
# > loaded cloudy55.jpg (150, 150, 3)
# > global features cloudy55.jpg (84,)
# > loaded cloudy56.jpg (150, 150, 3)
# > global features cloudy56.jpg (84,)
# > loaded cloudy57.jpg (150, 150, 3)
# > global features cloudy57.jpg (84,)
# > loaded cloudy58.jpg (150, 150, 3)
# > global features cloudy58.jpg (84,)
# > loaded cloudy59.jpg (150, 150, 3)
# > global features cloudy59.jpg (84,)
# > loaded cloudy6.jpg (150, 150, 3)
# > global features cloudy6.jpg (84,)
# > loaded cloudy60.jpg (150, 150, 3)
# > global features cloudy60.jpg (84,)
# > loaded cloudy61.jpg (150, 150, 3)
# > global features cloudy61.jpg (84,)
# > loaded cloudy62.jpg (150, 150, 3)
# > global features cloudy62.jpg (84,)
# > loaded cloudy63.jpg (150, 150, 3)
# > global features cloudy63.jpg (84,)
# > loaded cloudy64.jpg (150, 150, 3)
# > global features cloudy64.jpg (84,)
# > loaded cloudy65.jpg (150, 150, 3)
# > global features cloudy65.jpg (84,)
# > loaded cloudy66.jpg (150, 150, 3)
# > global features cloudy66.jpg (84,)
# > loaded cloudy67.jpg (150, 150, 3)
# > global features cloudy67.jpg (84,)
# > loaded cloudy68.jpg (150, 150, 3)
# > global features cloudy68.jpg (84,)
# > loaded cloudy69.jpg (150, 150, 3)
# > global features cloudy69.jpg (84,)
# > loaded cloudy7.jpg (150, 150, 3)
# > global features cloudy7.jpg (84,)
# > loaded cloudy70.jpg (150, 150, 3)
# > global features cloudy70.jpg (84,)
# > loaded cloudy71.jpg (150, 150, 3)
# > global features cloudy71.jpg (84,)
# > loaded cloudy72.jpg (150, 150, 3)
# > global features cloudy72.jpg (84,)
# > loaded cloudy73.jpg (150, 150, 3)
# > global features cloudy73.jpg (84,)
# > loaded cloudy74.jpg (150, 150, 3)
# > global features cloudy74.jpg (84,)
# > loaded cloudy75.jpg (150, 150, 3)
# > global features cloudy75.jpg (84,)
# > loaded cloudy76.jpg (150, 150, 3)
# > global features cloudy76.jpg (84,)
# > loaded cloudy77.jpg (150, 150, 3)
# > global features cloudy77.jpg (84,)
# > loaded cloudy78.jpg (150, 150, 3)
# > global features cloudy78.jpg (84,)
# > loaded cloudy79.jpg (150, 150, 3)
# > global features cloudy79.jpg (84,)
# > loaded cloudy8.jpg (150, 150, 3)
# > global features cloudy8.jpg (84,)
# > loaded cloudy80.jpg (150, 150, 3)
# > global features cloudy80.jpg (84,)
# > loaded cloudy81.jpg (150, 150, 3)
# > global features cloudy81.jpg (84,)
# > loaded cloudy82.jpg (150, 150, 3)
# > global features cloudy82.jpg (84,)
# > loaded cloudy83.jpg (150, 150, 3)
# > global features cloudy83.jpg (84,)
# > loaded cloudy84.jpg (150, 150, 3)
# > global features cloudy84.jpg (84,)
# > loaded cloudy85.jpg (150, 150, 3)
# > global features cloudy85.jpg (84,)
# > loaded cloudy86.jpg (150, 150, 3)
# > global features cloudy86.jpg (84,)
# > loaded cloudy87.jpg (150, 150, 3)
# > global features cloudy87.jpg (84,)
# > loaded cloudy88.jpg (150, 150, 3)
# > global features cloudy88.jpg (84,)
# > loaded cloudy89.jpg (150, 150, 3)
# > global features cloudy89.jpg (84,)
# > loaded cloudy9.jpg (150, 150, 3)
# > global features cloudy9.jpg (84,)
# > loaded cloudy90.jpg (150, 150, 3)
# > global features cloudy90.jpg (84,)
# > loaded cloudy91.jpg (150, 150, 3)
# > global features cloudy91.jpg (84,)
# > loaded cloudy92.jpg (150, 150, 3)
# > global features cloudy92.jpg (84,)
# > loaded cloudy93.jpg (150, 150, 3)
# > global features cloudy93.jpg (84,)
# > loaded cloudy94.jpg (150, 150, 3)
# > global features cloudy94.jpg (84,)
# > loaded cloudy95.jpg (150, 150, 3)
# > global features cloudy95.jpg (84,)
# > loaded cloudy96.jpg (150, 150, 3)
# > global features cloudy96.jpg (84,)
# > loaded cloudy97.jpg (150, 150, 3)
# > global features cloudy97.jpg (84,)
# > loaded cloudy98.jpg (150, 150, 3)
# > global features cloudy98.jpg (84,)
# > loaded cloudy99.jpg (150, 150, 3)
# > global features cloudy99.jpg (84,)
# > loaded rain1.jpg (150, 150, 3)
# > global features rain1.jpg (84,)
# > loaded rain10.jpg (150, 150, 3)
# > global features rain10.jpg (84,)
# > loaded rain100.jpg (150, 150, 3)
# > global features rain100.jpg (84,)
# > loaded rain101.jpg (150, 150, 3)
# > global features rain101.jpg (84,)
# > loaded rain102.jpg (150, 150, 3)
# > global features rain102.jpg (84,)
# > loaded rain103.jpg (150, 150, 3)
# > global features rain103.jpg (84,)
# > loaded rain104.jpg (150, 150, 3)
# > global features rain104.jpg (84,)
# > loaded rain105.jpg (150, 150, 3)
# > global features rain105.jpg (84,)
# > loaded rain106.jpg (150, 150, 3)
# > global features rain106.jpg (84,)
# > loaded rain107.jpg (150, 150, 3)
# > global features rain107.jpg (84,)
# > loaded rain108.jpg (150, 150, 3)
# > global features rain108.jpg (84,)
# > loaded rain109.jpg (150, 150, 3)
# > global features rain109.jpg (84,)
# > loaded rain11.jpg (150, 150, 3)
# > global features rain11.jpg (84,)
# > loaded rain110.jpg (150, 150, 3)
# > global features rain110.jpg (84,)
# > loaded rain111.jpg (150, 150, 3)
# > global features rain111.jpg (84,)
# > loaded rain112.jpg (150, 150, 3)
# > global features rain112.jpg (84,)
# > loaded rain113.jpg (150, 150, 3)
# > global features rain113.jpg (84,)
# > loaded rain114.jpg (150, 150, 3)
# > global features rain114.jpg (84,)
# > loaded rain115.jpg (150, 150, 3)
# > global features rain115.jpg (84,)
# > loaded rain116.jpg (150, 150, 3)
# > global features rain116.jpg (84,)
# > loaded rain117.jpg (150, 150, 3)
# > global features rain117.jpg (84,)
# > loaded rain118.jpg (150, 150, 3)
# > global features rain118.jpg (84,)
# > loaded rain119.jpg (150, 150, 3)
# > global features rain119.jpg (84,)
# > loaded rain12.jpg (150, 150, 3)
# > global features rain12.jpg (84,)
# > loaded rain120.jpg (150, 150, 3)
# > global features rain120.jpg (84,)
# > loaded rain121.jpg (150, 150, 3)
# > global features rain121.jpg (84,)
# > loaded rain122.jpg (150, 150, 3)
# > global features rain122.jpg (84,)
# > loaded rain123.jpg (150, 150, 3)
# > global features rain123.jpg (84,)
# > loaded rain124.jpg (150, 150, 3)
# > global features rain124.jpg (84,)
# > loaded rain125.jpg (150, 150, 3)
# > global features rain125.jpg (84,)
# > loaded rain126.jpg (150, 150, 3)
# > global features rain126.jpg (84,)
# > loaded rain127.jpg (150, 150, 3)
# > global features rain127.jpg (84,)
# > loaded rain128.jpg (150, 150, 3)
# > global features rain128.jpg (84,)
# > loaded rain129.jpg (150, 150, 3)
# > global features rain129.jpg (84,)
# > loaded rain13.jpg (150, 150, 3)
# > global features rain13.jpg (84,)
# > loaded rain130.jpg (150, 150, 3)
# > global features rain130.jpg (84,)
# > loaded rain131.jpg (150, 150, 3)
# > global features rain131.jpg (84,)
# > loaded rain132.jpg (150, 150, 3)
# > global features rain132.jpg (84,)
# > loaded rain133.jpg (150, 150, 3)
# > global features rain133.jpg (84,)
# > loaded rain134.jpg (150, 150, 3)
# > global features rain134.jpg (84,)
# > loaded rain135.jpg (150, 150, 3)
# > global features rain135.jpg (84,)
# > loaded rain136.jpg (150, 150, 3)
# > global features rain136.jpg (84,)
# > loaded rain137.jpg (150, 150, 3)
# > global features rain137.jpg (84,)
# > loaded rain138.jpg (150, 150, 3)
# > global features rain138.jpg (84,)
# > loaded rain139.jpg (150, 150, 3)
# > global features rain139.jpg (84,)
# > loaded rain14.jpg (150, 150, 3)
# > global features rain14.jpg (84,)
# > loaded rain140.jpg (150, 150, 3)
# > global features rain140.jpg (84,)
# > loaded rain142.jpg (150, 150, 3)
# > global features rain142.jpg (84,)
# > loaded rain143.jpg (150, 150, 3)
# > global features rain143.jpg (84,)
# > loaded rain144.jpg (150, 150, 3)
# > global features rain144.jpg (84,)
# > loaded rain145.jpg (150, 150, 3)
# > global features rain145.jpg (84,)
# > loaded rain146.jpg (150, 150, 3)
# > global features rain146.jpg (84,)
# > loaded rain147.jpg (150, 150, 3)
# > global features rain147.jpg (84,)
# > loaded rain148.jpg (150, 150, 3)
# > global features rain148.jpg (84,)
# > loaded rain149.jpg (150, 150, 3)
# > global features rain149.jpg (84,)
# > loaded rain15.jpg (150, 150, 3)
# > global features rain15.jpg (84,)
# > loaded rain150.jpg (150, 150, 3)
# > global features rain150.jpg (84,)
# > loaded rain151.jpg (150, 150, 3)
# > global features rain151.jpg (84,)
# > loaded rain152.jpg (150, 150, 3)
# > global features rain152.jpg (84,)
# > loaded rain153.jpg (150, 150, 3)
# > global features rain153.jpg (84,)
# > loaded rain154.jpg (150, 150, 3)
# > global features rain154.jpg (84,)
# > loaded rain155.jpg (150, 150, 3)
# > global features rain155.jpg (84,)
# > loaded rain156.jpg (150, 150, 3)
# > global features rain156.jpg (84,)
# > loaded rain157.jpg (150, 150, 3)
# > global features rain157.jpg (84,)
# > loaded rain158.jpg (150, 150, 3)
# > global features rain158.jpg (84,)
# > loaded rain159.jpg (150, 150, 3)
# > global features rain159.jpg (84,)
# > loaded rain16.jpg (150, 150, 3)
# > global features rain16.jpg (84,)
# > loaded rain160.jpg (150, 150, 3)
# > global features rain160.jpg (84,)
# > loaded rain161.jpg (150, 150, 3)
# > global features rain161.jpg (84,)
# > loaded rain162.jpg (150, 150, 3)
# > global features rain162.jpg (84,)
# > loaded rain163.jpg (150, 150, 3)
# > global features rain163.jpg (84,)
# > loaded rain164.jpg (150, 150, 3)
# > global features rain164.jpg (84,)
# > loaded rain165.jpg (150, 150, 3)
# > global features rain165.jpg (84,)
# > loaded rain166.jpg (150, 150, 3)
# > global features rain166.jpg (84,)
# > loaded rain167.jpg (150, 150, 3)
# > global features rain167.jpg (84,)
# > loaded rain168.jpg (150, 150, 3)
# > global features rain168.jpg (84,)
# > loaded rain169.jpg (150, 150, 3)
# > global features rain169.jpg (84,)
# > loaded rain17.jpg (150, 150, 3)
# > global features rain17.jpg (84,)
# > loaded rain170.jpg (150, 150, 3)
# > global features rain170.jpg (84,)
# > loaded rain171.jpg (150, 150, 3)
# > global features rain171.jpg (84,)
# > loaded rain172.jpg (150, 150, 3)
# > global features rain172.jpg (84,)
# > loaded rain173.jpg (150, 150, 3)
# > global features rain173.jpg (84,)
# > loaded rain174.jpg (150, 150, 3)
# > global features rain174.jpg (84,)
# > loaded rain175.jpg (150, 150, 3)
# > global features rain175.jpg (84,)
# > loaded rain176.jpg (150, 150, 3)
# > global features rain176.jpg (84,)
# > loaded rain177.jpg (150, 150, 3)
# > global features rain177.jpg (84,)
# > loaded rain178.jpg (150, 150, 3)
# > global features rain178.jpg (84,)
# > loaded rain179.jpg (150, 150, 3)
# > global features rain179.jpg (84,)
# > loaded rain18.jpg (150, 150, 3)
# > global features rain18.jpg (84,)
# > loaded rain180.jpg (150, 150, 3)
# > global features rain180.jpg (84,)
# > loaded rain181.jpg (150, 150, 3)
# > global features rain181.jpg (84,)
# > loaded rain182.jpg (150, 150, 3)
# > global features rain182.jpg (84,)
# > loaded rain183.jpg (150, 150, 3)
# > global features rain183.jpg (84,)
# > loaded rain184.jpg (150, 150, 3)
# > global features rain184.jpg (84,)
# > loaded rain185.jpg (150, 150, 3)
# > global features rain185.jpg (84,)
# > loaded rain186.jpg (150, 150, 3)
# > global features rain186.jpg (84,)
# > loaded rain187.jpg (150, 150, 3)
# > global features rain187.jpg (84,)
# > loaded rain188.jpg (150, 150, 3)
# > global features rain188.jpg (84,)
# > loaded rain189.jpg (150, 150, 3)
# > global features rain189.jpg (84,)
# > loaded rain19.jpg (150, 150, 3)
# > global features rain19.jpg (84,)
# > loaded rain190.jpg (150, 150, 3)
# > global features rain190.jpg (84,)
# > loaded rain191.jpg (150, 150, 3)
# > global features rain191.jpg (84,)
# > loaded rain192.jpg (150, 150, 3)
# > global features rain192.jpg (84,)
# > loaded rain193.jpg (150, 150, 3)
# > global features rain193.jpg (84,)
# > loaded rain194.jpg (150, 150, 3)
# > global features rain194.jpg (84,)
# > loaded rain195.jpg (150, 150, 3)
# > global features rain195.jpg (84,)
# > loaded rain196.jpg (150, 150, 3)
# > global features rain196.jpg (84,)
# > loaded rain197.jpg (150, 150, 3)
# > global features rain197.jpg (84,)
# > loaded rain198.jpg (150, 150, 3)
# > global features rain198.jpg (84,)
# > loaded rain199.jpg (150, 150, 3)
# > global features rain199.jpg (84,)
# > loaded rain2.jpg (150, 150, 3)
# > global features rain2.jpg (84,)
# > loaded rain20.jpg (150, 150, 3)
# > global features rain20.jpg (84,)
# > loaded rain200.jpg (150, 150, 3)
# > global features rain200.jpg (84,)
# > loaded rain201.jpg (150, 150, 3)
# > global features rain201.jpg (84,)
# > loaded rain202.jpg (150, 150, 3)
# > global features rain202.jpg (84,)
# > loaded rain203.jpg (150, 150, 3)
# > global features rain203.jpg (84,)
# > loaded rain204.jpg (150, 150, 3)
# > global features rain204.jpg (84,)
# > loaded rain205.jpg (150, 150, 3)
# > global features rain205.jpg (84,)
# > loaded rain206.jpg (150, 150, 3)
# > global features rain206.jpg (84,)
# > loaded rain207.jpg (150, 150, 3)
# > global features rain207.jpg (84,)
# > loaded rain208.jpg (150, 150, 3)
# > global features rain208.jpg (84,)
# > loaded rain209.jpg (150, 150, 3)
# > global features rain209.jpg (84,)
# > loaded rain21.jpg (150, 150, 3)
# > global features rain21.jpg (84,)
# > loaded rain210.jpg (150, 150, 3)
# > global features rain210.jpg (84,)
# > loaded rain211.jpg (150, 150, 3)
# > global features rain211.jpg (84,)
# > loaded rain212.jpg (150, 150, 3)
# > global features rain212.jpg (84,)
# > loaded rain213.jpg (150, 150, 3)
# > global features rain213.jpg (84,)
# > loaded rain214.jpg (150, 150, 3)
# > global features rain214.jpg (84,)
# > loaded rain215.jpg (150, 150, 3)
# > global features rain215.jpg (84,)
# > loaded rain22.jpeg (150, 150, 3)
# > global features rain22.jpeg (84,)
# > loaded rain23.jpg (150, 150, 3)
# > global features rain23.jpg (84,)
# > loaded rain24.jpeg (150, 150, 3)
# > global features rain24.jpeg (84,)
# > loaded rain25.jpg (150, 150, 3)
# > global features rain25.jpg (84,)
# > loaded rain26.jpg (150, 150, 3)
# > global features rain26.jpg (84,)
# > loaded rain27.jpg (150, 150, 3)
# > global features rain27.jpg (84,)
# > loaded rain28.jpg (150, 150, 3)
# > global features rain28.jpg (84,)
# > loaded rain29.jpg (150, 150, 3)
# > global features rain29.jpg (84,)
# > loaded rain3.jpg (150, 150, 3)
# > global features rain3.jpg (84,)
# > loaded rain30.jpg (150, 150, 3)
# > global features rain30.jpg (84,)
# > loaded rain31.jpg (150, 150, 3)
# > global features rain31.jpg (84,)
# > loaded rain32.jpg (150, 150, 3)
# > global features rain32.jpg (84,)
# > loaded rain33.jpg (150, 150, 3)
# > global features rain33.jpg (84,)
# > loaded rain34.jpg (150, 150, 3)
# > global features rain34.jpg (84,)
# > loaded rain35.jpg (150, 150, 3)
# > global features rain35.jpg (84,)
# > loaded rain36.jpg (150, 150, 3)
# > global features rain36.jpg (84,)
# > loaded rain37.jpg (150, 150, 3)
# > global features rain37.jpg (84,)
# > loaded rain38.jpg (150, 150, 3)
# > global features rain38.jpg (84,)
# > loaded rain39.jpg (150, 150, 3)
# > global features rain39.jpg (84,)
# > loaded rain4.jpg (150, 150, 3)
# > global features rain4.jpg (84,)
# > loaded rain40.jpg (150, 150, 3)
# > global features rain40.jpg (84,)
# > loaded rain41.jpg (150, 150, 3)
# > global features rain41.jpg (84,)
# > loaded rain42.jpg (150, 150, 3)
# > global features rain42.jpg (84,)
# > loaded rain43.jpg (150, 150, 3)
# > global features rain43.jpg (84,)
# > loaded rain44.jpg (150, 150, 3)
# > global features rain44.jpg (84,)
# > loaded rain45.jpg (150, 150, 3)
# > global features rain45.jpg (84,)
# > loaded rain46.jpg (150, 150, 3)
# > global features rain46.jpg (84,)
# > loaded rain47.jpg (150, 150, 3)
# > global features rain47.jpg (84,)
# > loaded rain48.jpg (150, 150, 3)
# > global features rain48.jpg (84,)
# > loaded rain49.jpg (150, 150, 3)
# > global features rain49.jpg (84,)
# > loaded rain5.jpg (150, 150, 3)
# > global features rain5.jpg (84,)
# > loaded rain50.jpg (150, 150, 3)
# > global features rain50.jpg (84,)
# > loaded rain51.jpg (150, 150, 3)
# > global features rain51.jpg (84,)
# > loaded rain52.jpg (150, 150, 3)
# > global features rain52.jpg (84,)
# > loaded rain53.jpg (150, 150, 3)
# > global features rain53.jpg (84,)
# > loaded rain54.jpg (150, 150, 3)
# > global features rain54.jpg (84,)
# > loaded rain55.jpg (150, 150, 3)
# > global features rain55.jpg (84,)
# > loaded rain56.jpg (150, 150, 3)
# > global features rain56.jpg (84,)
# > loaded rain57.jpg (150, 150, 3)
# > global features rain57.jpg (84,)
# > loaded rain58.jpg (150, 150, 3)
# > global features rain58.jpg (84,)
# > loaded rain59.jpg (150, 150, 3)
# > global features rain59.jpg (84,)
# > loaded rain6.jpg (150, 150, 3)
# > global features rain6.jpg (84,)
# > loaded rain60.jpg (150, 150, 3)
# > global features rain60.jpg (84,)
# > loaded rain61.jpg (150, 150, 3)
# > global features rain61.jpg (84,)
# > loaded rain62.jpg (150, 150, 3)
# > global features rain62.jpg (84,)
# > loaded rain63.jpg (150, 150, 3)
# > global features rain63.jpg (84,)
# > loaded rain64.jpg (150, 150, 3)
# > global features rain64.jpg (84,)
# > loaded rain65.jpg (150, 150, 3)
# > global features rain65.jpg (84,)
# > loaded rain66.jpg (150, 150, 3)
# > global features rain66.jpg (84,)
# > loaded rain67.jpg (150, 150, 3)
# > global features rain67.jpg (84,)
# > loaded rain68.jpg (150, 150, 3)
# > global features rain68.jpg (84,)
# > loaded rain69.jpg (150, 150, 3)
# > global features rain69.jpg (84,)
# > loaded rain7.jpg (150, 150, 3)
# > global features rain7.jpg (84,)
# > loaded rain70.jpg (150, 150, 3)
# > global features rain70.jpg (84,)
# > loaded rain71.jpg (150, 150, 3)
# > global features rain71.jpg (84,)
# > loaded rain72.jpg (150, 150, 3)
# > global features rain72.jpg (84,)
# > loaded rain73.jpg (150, 150, 3)
# > global features rain73.jpg (84,)
# > loaded rain74.jpg (150, 150, 3)
# > global features rain74.jpg (84,)
# > loaded rain75.jpg (150, 150, 3)
# > global features rain75.jpg (84,)
# > loaded rain76.jpg (150, 150, 3)
# > global features rain76.jpg (84,)
# > loaded rain77.jpg (150, 150, 3)
# > global features rain77.jpg (84,)
# > loaded rain78.jpg (150, 150, 3)
# > global features rain78.jpg (84,)
# > loaded rain79.jpg (150, 150, 3)
# > global features rain79.jpg (84,)
# > loaded rain8.jpg (150, 150, 3)
# > global features rain8.jpg (84,)
# > loaded rain80.jpg (150, 150, 3)
# > global features rain80.jpg (84,)
# > loaded rain81.jpg (150, 150, 3)
# > global features rain81.jpg (84,)
# > loaded rain82.jpg (150, 150, 3)
# > global features rain82.jpg (84,)
# > loaded rain83.jpg (150, 150, 3)
# > global features rain83.jpg (84,)
# > loaded rain84.jpg (150, 150, 3)
# > global features rain84.jpg (84,)
# > loaded rain85.jpg (150, 150, 3)
# > global features rain85.jpg (84,)
# > loaded rain86.jpg (150, 150, 3)
# > global features rain86.jpg (84,)
# > loaded rain87.jpg (150, 150, 3)
# > global features rain87.jpg (84,)
# > loaded rain88.jpg (150, 150, 3)
# > global features rain88.jpg (84,)
# > loaded rain89.jpg (150, 150, 3)
# > global features rain89.jpg (84,)
# > loaded rain9.jpg (150, 150, 3)
# > global features rain9.jpg (84,)
# > loaded rain90.jpg (150, 150, 3)
# > global features rain90.jpg (84,)
# > loaded rain91.jpg (150, 150, 3)
# > global features rain91.jpg (84,)
# > loaded rain92.jpg (150, 150, 3)
# > global features rain92.jpg (84,)
# > loaded rain93.jpg (150, 150, 3)
# > global features rain93.jpg (84,)
# > loaded rain94.jpg (150, 150, 3)
# > global features rain94.jpg (84,)
# > loaded rain95.jpg (150, 150, 3)
# > global features rain95.jpg (84,)
# > loaded rain96.jpg (150, 150, 3)
# > global features rain96.jpg (84,)
# > loaded rain97.jpg (150, 150, 3)
# > global features rain97.jpg (84,)
# > loaded rain98.jpg (150, 150, 3)
# > global features rain98.jpg (84,)
# > loaded rain99.jpg (150, 150, 3)
# > global features rain99.jpg (84,)
# > loaded shine1.jpg (150, 150, 3)
# > global features shine1.jpg (84,)
# > loaded shine10.jpg (150, 150, 3)
# > global features shine10.jpg (84,)
# > loaded shine100.jpg (150, 150, 3)
# > global features shine100.jpg (84,)
# > loaded shine101.jpg (150, 150, 3)
# > global features shine101.jpg (84,)
# > loaded shine102.jpg (150, 150, 3)
# > global features shine102.jpg (84,)
# > loaded shine103.jpg (150, 150, 3)
# > global features shine103.jpg (84,)
# > loaded shine104.jpg (150, 150, 3)
# > global features shine104.jpg (84,)
# > loaded shine105.jpg (150, 150, 3)
# > global features shine105.jpg (84,)
# > loaded shine106.jpg (150, 150, 3)
# > global features shine106.jpg (84,)
# > loaded shine107.jpg (150, 150, 3)
# > global features shine107.jpg (84,)
# > loaded shine108.jpg (150, 150, 3)
# > global features shine108.jpg (84,)
# > loaded shine109.jpg (150, 150, 3)
# > global features shine109.jpg (84,)
# > loaded shine11.jpg (150, 150, 3)
# > global features shine11.jpg (84,)
# > loaded shine110.jpg (150, 150, 3)
# > global features shine110.jpg (84,)
# > loaded shine111.jpg (150, 150, 3)
# > global features shine111.jpg (84,)
# > loaded shine112.jpg (150, 150, 3)
# > global features shine112.jpg (84,)
# > loaded shine113.jpg (150, 150, 3)
# > global features shine113.jpg (84,)
# > loaded shine114.jpg (150, 150, 3)
# > global features shine114.jpg (84,)
# > loaded shine115.jpg (150, 150, 3)
# > global features shine115.jpg (84,)
# > loaded shine116.jpg (150, 150, 3)
# > global features shine116.jpg (84,)
# > loaded shine117.jpg (150, 150, 3)
# > global features shine117.jpg (84,)
# > loaded shine118.jpg (150, 150, 3)
# > global features shine118.jpg (84,)
# > loaded shine119.jpg (150, 150, 3)
# > global features shine119.jpg (84,)
# > loaded shine12.jpg (150, 150, 3)
# > global features shine12.jpg (84,)
# > loaded shine120.jpg (150, 150, 3)
# > global features shine120.jpg (84,)
# > loaded shine121.jpg (150, 150, 3)
# > global features shine121.jpg (84,)
# > loaded shine122.jpg (150, 150, 3)
# > global features shine122.jpg (84,)
# > loaded shine123.jpg (150, 150, 3)
# > global features shine123.jpg (84,)
# > loaded shine124.jpg (150, 150, 3)
# > global features shine124.jpg (84,)
# > loaded shine125.jpg (150, 150, 3)
# > global features shine125.jpg (84,)
# > loaded shine126.jpg (150, 150, 3)
# > global features shine126.jpg (84,)
# > loaded shine127.jpg (150, 150, 3)
# > global features shine127.jpg (84,)
# > loaded shine128.jpg (150, 150, 3)
# > global features shine128.jpg (84,)
# > loaded shine129.jpg (150, 150, 3)
# > global features shine129.jpg (84,)
# > loaded shine13.jpg (150, 150, 3)
# > global features shine13.jpg (84,)
# > loaded shine130.jpg (150, 150, 3)
# > global features shine130.jpg (84,)
# > loaded shine132.jpg (150, 150, 3)
# > global features shine132.jpg (84,)
# > loaded shine133.jpg (150, 150, 3)
# > global features shine133.jpg (84,)
# > loaded shine134.jpg (150, 150, 3)
# > global features shine134.jpg (84,)
# > loaded shine135.jpg (150, 150, 3)
# > global features shine135.jpg (84,)
# > loaded shine136.jpg (150, 150, 3)
# > global features shine136.jpg (84,)
# > loaded shine137.jpg (150, 150, 3)
# > global features shine137.jpg (84,)
# > loaded shine138.jpg (150, 150, 3)
# > global features shine138.jpg (84,)
# > loaded shine139.jpg (150, 150, 3)
# > global features shine139.jpg (84,)
# > loaded shine14.jpg (150, 150, 3)
# > global features shine14.jpg (84,)
# > loaded shine140.jpg (150, 150, 3)
# > global features shine140.jpg (84,)
# > loaded shine141.jpg (150, 150, 3)
# > global features shine141.jpg (84,)
# > loaded shine142.jpg (150, 150, 3)
# > global features shine142.jpg (84,)
# > loaded shine143.jpg (150, 150, 3)
# > global features shine143.jpg (84,)
# > loaded shine144.jpg (150, 150, 3)
# > global features shine144.jpg (84,)
# > loaded shine145.jpg (150, 150, 3)
# > global features shine145.jpg (84,)
# > loaded shine146.jpg (150, 150, 3)
# > global features shine146.jpg (84,)
# > loaded shine147.jpg (150, 150, 3)
# > global features shine147.jpg (84,)
# > loaded shine148.jpg (150, 150, 3)
# > global features shine148.jpg (84,)
# > loaded shine149.jpg (150, 150, 3)
# > global features shine149.jpg (84,)
# > loaded shine15.jpg (150, 150, 3)
# > global features shine15.jpg (84,)
# > loaded shine150.jpg (150, 150, 3)
# > global features shine150.jpg (84,)
# > loaded shine151.jpg (150, 150, 3)
# > global features shine151.jpg (84,)
# > loaded shine152.jpg (150, 150, 3)
# > global features shine152.jpg (84,)
# > loaded shine153.jpg (150, 150, 3)
# > global features shine153.jpg (84,)
# > loaded shine154.jpg (150, 150, 3)
# > global features shine154.jpg (84,)
# > loaded shine155.jpg (150, 150, 3)
# > global features shine155.jpg (84,)
# > loaded shine156.jpg (150, 150, 3)
# > global features shine156.jpg (84,)
# > loaded shine157.jpg (150, 150, 3)
# > global features shine157.jpg (84,)
# > loaded shine158.jpg (150, 150, 3)
# > global features shine158.jpg (84,)
# > loaded shine159.jpg (150, 150, 3)
# > global features shine159.jpg (84,)
# > loaded shine16.jpg (150, 150, 3)
# > global features shine16.jpg (84,)
# > loaded shine160.jpg (150, 150, 3)
# > global features shine160.jpg (84,)
# > loaded shine161.jpg (150, 150, 3)
# > global features shine161.jpg (84,)
# > loaded shine162.jpg (150, 150, 3)
# > global features shine162.jpg (84,)
# > loaded shine163.jpg (150, 150, 3)
# > global features shine163.jpg (84,)
# > loaded shine164.jpg (150, 150, 3)
# > global features shine164.jpg (84,)
# > loaded shine165.jpg (150, 150, 3)
# > global features shine165.jpg (84,)
# > loaded shine166.jpg (150, 150, 3)
# > global features shine166.jpg (84,)
# > loaded shine167.jpg (150, 150, 3)
# > global features shine167.jpg (84,)
# > loaded shine168.jpg (150, 150, 3)
# > global features shine168.jpg (84,)
# > loaded shine169.jpg (150, 150, 3)
# > global features shine169.jpg (84,)
# > loaded shine17.jpg (150, 150, 3)
# > global features shine17.jpg (84,)
# > loaded shine170.jpg (150, 150, 3)
# > global features shine170.jpg (84,)
# > loaded shine171.jpg (150, 150, 3)
# > global features shine171.jpg (84,)
# > loaded shine172.jpg (150, 150, 3)
# > global features shine172.jpg (84,)
# > loaded shine173.jpg (150, 150, 3)
# > global features shine173.jpg (84,)
# > loaded shine174.jpg (150, 150, 3)
# > global features shine174.jpg (84,)
# > loaded shine175.jpg (150, 150, 3)
# > global features shine175.jpg (84,)
# > loaded shine176.jpg (150, 150, 3)
# > global features shine176.jpg (84,)
# > loaded shine177.jpg (150, 150, 3)
# > global features shine177.jpg (84,)
# > loaded shine178.jpg (150, 150, 3)
# > global features shine178.jpg (84,)
# > loaded shine179.jpg (150, 150, 3)
# > global features shine179.jpg (84,)
# > loaded shine18.jpg (150, 150, 3)
# > global features shine18.jpg (84,)
# > loaded shine180.jpg (150, 150, 3)
# > global features shine180.jpg (84,)
# > loaded shine181.jpg (150, 150, 3)
# > global features shine181.jpg (84,)
# > loaded shine182.jpg (150, 150, 3)
# > global features shine182.jpg (84,)
# > loaded shine183.jpg (150, 150, 3)
# > global features shine183.jpg (84,)
# > loaded shine184.jpg (150, 150, 3)
# > global features shine184.jpg (84,)
# > loaded shine185.jpg (150, 150, 3)
# > global features shine185.jpg (84,)
# > loaded shine186.jpg (150, 150, 3)
# > global features shine186.jpg (84,)
# > loaded shine187.jpg (150, 150, 3)
# > global features shine187.jpg (84,)
# > loaded shine188.jpg (150, 150, 3)
# > global features shine188.jpg (84,)
# > loaded shine189.jpg (150, 150, 3)
# > global features shine189.jpg (84,)
# > loaded shine19.jpg (150, 150, 3)
# > global features shine19.jpg (84,)
# > loaded shine190.jpg (150, 150, 3)
# > global features shine190.jpg (84,)
# > loaded shine191.jpg (150, 150, 3)
# > global features shine191.jpg (84,)
# > loaded shine192.jpg (150, 150, 3)
# > global features shine192.jpg (84,)
# > loaded shine193.jpg (150, 150, 3)
# > global features shine193.jpg (84,)
# > loaded shine194.jpg (150, 150, 3)
# > global features shine194.jpg (84,)
# > loaded shine195.jpg (150, 150, 3)
# > global features shine195.jpg (84,)
# > loaded shine196.jpg (150, 150, 3)
# > global features shine196.jpg (84,)
# > loaded shine197.jpg (150, 150, 3)
# > global features shine197.jpg (84,)
# > loaded shine198.jpg (150, 150, 3)
# > global features shine198.jpg (84,)
# > loaded shine199.jpg (150, 150, 3)
# > global features shine199.jpg (84,)
# > loaded shine2.jpg (150, 150, 3)
# > global features shine2.jpg (84,)
# > loaded shine20.jpg (150, 150, 3)
# > global features shine20.jpg (84,)
# > loaded shine200.jpg (150, 150, 3)
# > global features shine200.jpg (84,)
# > loaded shine201.jpg (150, 150, 3)
# > global features shine201.jpg (84,)
# > loaded shine202.jpg (150, 150, 3)
# > global features shine202.jpg (84,)
# > loaded shine203.jpg (150, 150, 3)
# > global features shine203.jpg (84,)
# > loaded shine204.jpg (150, 150, 3)
# > global features shine204.jpg (84,)
# > loaded shine205.jpg (150, 150, 3)
# > global features shine205.jpg (84,)
# > loaded shine206.jpg (150, 150, 3)
# > global features shine206.jpg (84,)
# > loaded shine207.jpg (150, 150, 3)
# > global features shine207.jpg (84,)
# > loaded shine208.jpg (150, 150, 3)
# > global features shine208.jpg (84,)
# > loaded shine209.jpg (150, 150, 3)
# > global features shine209.jpg (84,)
# > loaded shine21.jpg (150, 150, 3)
# > global features shine21.jpg (84,)
# > loaded shine210.jpg (150, 150, 3)
# > global features shine210.jpg (84,)
# > loaded shine211.jpg (150, 150, 3)
# > global features shine211.jpg (84,)
# > loaded shine212.jpg (150, 150, 3)
# > global features shine212.jpg (84,)
# > loaded shine213.jpg (150, 150, 3)
# > global features shine213.jpg (84,)
# > loaded shine214.jpg (150, 150, 3)
# > global features shine214.jpg (84,)
# > loaded shine215.jpg (150, 150, 3)
# > global features shine215.jpg (84,)
# > loaded shine216.jpg (150, 150, 3)
# > global features shine216.jpg (84,)
# > loaded shine217.jpg (150, 150, 3)
# > global features shine217.jpg (84,)
# > loaded shine218.jpg (150, 150, 3)
# > global features shine218.jpg (84,)
# > loaded shine219.jpg (150, 150, 3)
# > global features shine219.jpg (84,)
# > loaded shine22.jpg (150, 150, 3)
# > global features shine22.jpg (84,)
# > loaded shine220.jpg (150, 150, 3)
# > global features shine220.jpg (84,)
# > loaded shine221.jpg (150, 150, 3)
# > global features shine221.jpg (84,)
# > loaded shine222.jpg (150, 150, 3)
# > global features shine222.jpg (84,)
# > loaded shine223.jpg (150, 150, 3)
# > global features shine223.jpg (84,)
# > loaded shine224.jpg (150, 150, 3)
# > global features shine224.jpg (84,)
# > loaded shine225.jpg (150, 150, 3)
# > global features shine225.jpg (84,)
# > loaded shine226.jpg (150, 150, 3)
# > global features shine226.jpg (84,)
# > loaded shine227.jpg (150, 150, 3)
# > global features shine227.jpg (84,)
# > loaded shine228.jpg (150, 150, 3)
# > global features shine228.jpg (84,)
# > loaded shine229.jpg (150, 150, 3)
# > global features shine229.jpg (84,)
# > loaded shine23.jpg (150, 150, 3)
# > global features shine23.jpg (84,)
# > loaded shine230.jpg (150, 150, 3)
# > global features shine230.jpg (84,)
# > loaded shine231.jpg (150, 150, 3)
# > global features shine231.jpg (84,)
# > loaded shine232.jpg (150, 150, 3)
# ...
# > loaded sunrise232.jpg (150, 150, 3)
# > global features sunrise232.jpg (84,)
# > loaded sunrise233.jpg (150, 150, 3)
# > global features sunrise233.jpg (84,)
# > loaded sunrise234.jpg (150, 150, 3)
# > global features sunrise234.jpg (84,)
# > loaded sunrise235.jpg (150, 150, 3)
# > global features sunrise235.jpg (84,)
# > loaded sunrise236.jpg (150, 150, 3)
# > global features sunrise236.jpg (84,)
# > loaded sunrise237.jpg (150, 150, 3)
# > global features sunrise237.jpg (84,)
# > loaded sunrise238.jpg (150, 150, 3)
# > global features sunrise238.jpg (84,)
# > loaded sunrise239.jpg (150, 150, 3)
# > global features sunrise239.jpg (84,)
# > loaded sunrise24.jpg (150, 150, 3)
# > global features sunrise24.jpg (84,)
# > loaded sunrise240.jpg (150, 150, 3)
# > global features sunrise240.jpg (84,)
# > loaded sunrise241.jpg (150, 150, 3)
# > global features sunrise241.jpg (84,)
# > loaded sunrise242.jpg (150, 150, 3)
# > global features sunrise242.jpg (84,)
# > loaded sunrise243.jpg (150, 150, 3)
# > global features sunrise243.jpg (84,)
# > loaded sunrise244.jpg (150, 150, 3)
# > global features sunrise244.jpg (84,)
# > loaded sunrise245.jpg (150, 150, 3)
# > global features sunrise245.jpg (84,)
# > loaded sunrise246.jpg (150, 150, 3)
# > global features sunrise246.jpg (84,)
# > loaded sunrise247.jpg (150, 150, 3)
# > global features sunrise247.jpg (84,)
# > loaded sunrise248.jpg (150, 150, 3)
# > global features sunrise248.jpg (84,)
# > loaded sunrise249.jpg (150, 150, 3)
# > global features sunrise249.jpg (84,)
# > loaded sunrise25.jpg (150, 150, 3)
# > global features sunrise25.jpg (84,)
# > loaded sunrise250.jpg (150, 150, 3)
# > global features sunrise250.jpg (84,)
# > loaded sunrise251.jpg (150, 150, 3)
# > global features sunrise251.jpg (84,)
# > loaded sunrise252.jpg (150, 150, 3)
# > global features sunrise252.jpg (84,)
# > loaded sunrise253.jpg (150, 150, 3)
# > global features sunrise253.jpg (84,)
# > loaded sunrise254.jpg (150, 150, 3)
# > global features sunrise254.jpg (84,)
# > loaded sunrise255.jpg (150, 150, 3)
# > global features sunrise255.jpg (84,)
# > loaded sunrise256.jpg (150, 150, 3)
# > global features sunrise256.jpg (84,)
# > loaded sunrise257.jpg (150, 150, 3)
# > global features sunrise257.jpg (84,)
# > loaded sunrise258.jpg (150, 150, 3)
# > global features sunrise258.jpg (84,)
# > loaded sunrise259.jpg (150, 150, 3)
# > global features sunrise259.jpg (84,)
# > loaded sunrise26.jpg (150, 150, 3)
# > global features sunrise26.jpg (84,)
# > loaded sunrise260.jpg (150, 150, 3)
# > global features sunrise260.jpg (84,)
# > loaded sunrise261.jpg (150, 150, 3)
# > global features sunrise261.jpg (84,)
# > loaded sunrise262.jpg (150, 150, 3)
# > global features sunrise262.jpg (84,)
# > loaded sunrise263.jpg (150, 150, 3)
# > global features sunrise263.jpg (84,)
# > loaded sunrise264.jpg (150, 150, 3)
# > global features sunrise264.jpg (84,)
# > loaded sunrise265.jpg (150, 150, 3)
# > global features sunrise265.jpg (84,)
# > loaded sunrise266.jpg (150, 150, 3)
# > global features sunrise266.jpg (84,)
# > loaded sunrise267.jpg (150, 150, 3)
# > global features sunrise267.jpg (84,)
# > loaded sunrise268.jpg (150, 150, 3)
# > global features sunrise268.jpg (84,)
# > loaded sunrise269.jpg (150, 150, 3)
# > global features sunrise269.jpg (84,)
# > loaded sunrise27.jpg (150, 150, 3)
# > global features sunrise27.jpg (84,)
# > loaded sunrise270.jpg (150, 150, 3)
# > global features sunrise270.jpg (84,)
# > loaded sunrise271.jpg (150, 150, 3)
# > global features sunrise271.jpg (84,)
# > loaded sunrise272.jpg (150, 150, 3)
# > global features sunrise272.jpg (84,)
# > loaded sunrise273.jpg (150, 150, 3)
# > global features sunrise273.jpg (84,)
# > loaded sunrise274.jpg (150, 150, 3)
# > global features sunrise274.jpg (84,)
# > loaded sunrise275.jpg (150, 150, 3)
# > global features sunrise275.jpg (84,)
# > loaded sunrise276.jpg (150, 150, 3)
# > global features sunrise276.jpg (84,)
# > loaded sunrise277.jpg (150, 150, 3)
# > global features sunrise277.jpg (84,)
# > loaded sunrise278.jpg (150, 150, 3)
# > global features sunrise278.jpg (84,)
# > loaded sunrise279.jpg (150, 150, 3)
# > global features sunrise279.jpg (84,)
# > loaded sunrise28.jpg (150, 150, 3)
# > global features sunrise28.jpg (84,)
# > loaded sunrise280.jpg (150, 150, 3)
# > global features sunrise280.jpg (84,)
# > loaded sunrise281.jpg (150, 150, 3)
# > global features sunrise281.jpg (84,)
# > loaded sunrise282.jpg (150, 150, 3)
# > global features sunrise282.jpg (84,)
# > loaded sunrise283.jpg (150, 150, 3)
# > global features sunrise283.jpg (84,)
# > loaded sunrise284.jpg (150, 150, 3)
# > global features sunrise284.jpg (84,)
# > loaded sunrise285.jpg (150, 150, 3)
# > global features sunrise285.jpg (84,)
# > loaded sunrise286.jpg (150, 150, 3)
# > global features sunrise286.jpg (84,)
# > loaded sunrise287.jpg (150, 150, 3)
# > global features sunrise287.jpg (84,)
# > loaded sunrise288.jpg (150, 150, 3)
# > global features sunrise288.jpg (84,)
# > loaded sunrise289.jpg (150, 150, 3)
# > global features sunrise289.jpg (84,)
# > loaded sunrise29.jpg (150, 150, 3)
# > global features sunrise29.jpg (84,)
# > loaded sunrise290.jpg (150, 150, 3)
# > global features sunrise290.jpg (84,)
# > loaded sunrise291.jpg (150, 150, 3)
# > global features sunrise291.jpg (84,)
# > loaded sunrise292.jpg (150, 150, 3)
# > global features sunrise292.jpg (84,)
# > loaded sunrise293.jpg (150, 150, 3)
# > global features sunrise293.jpg (84,)
# > loaded sunrise294.jpg (150, 150, 3)
# > global features sunrise294.jpg (84,)
# > loaded sunrise295.jpg (150, 150, 3)
# > global features sunrise295.jpg (84,)
# > loaded sunrise296.jpg (150, 150, 3)
# > global features sunrise296.jpg (84,)
# > loaded sunrise297.jpg (150, 150, 3)
# > global features sunrise297.jpg (84,)
# > loaded sunrise298.jpg (150, 150, 3)
# > global features sunrise298.jpg (84,)
# > loaded sunrise299.jpg (150, 150, 3)
# > global features sunrise299.jpg (84,)
# > loaded sunrise3.jpg (150, 150, 3)
# > global features sunrise3.jpg (84,)
# > loaded sunrise30.jpg (150, 150, 3)
# > global features sunrise30.jpg (84,)
# > loaded sunrise300.jpg (150, 150, 3)
# > global features sunrise300.jpg (84,)
# > loaded sunrise301.jpg (150, 150, 3)
# > global features sunrise301.jpg (84,)
# > loaded sunrise302.jpg (150, 150, 3)
# > global features sunrise302.jpg (84,)
# > loaded sunrise303.jpg (150, 150, 3)
# > global features sunrise303.jpg (84,)
# > loaded sunrise304.jpg (150, 150, 3)
# > global features sunrise304.jpg (84,)
# > loaded sunrise305.jpg (150, 150, 3)
# > global features sunrise305.jpg (84,)
# > loaded sunrise306.jpg (150, 150, 3)
# > global features sunrise306.jpg (84,)
# > loaded sunrise307.jpg (150, 150, 3)
# > global features sunrise307.jpg (84,)
# > loaded sunrise308.jpg (150, 150, 3)
# > global features sunrise308.jpg (84,)
# > loaded sunrise309.jpg (150, 150, 3)
# > global features sunrise309.jpg (84,)
# > loaded sunrise31.jpg (150, 150, 3)
# > global features sunrise31.jpg (84,)
# > loaded sunrise310.jpg (150, 150, 3)
# > global features sunrise310.jpg (84,)
# > loaded sunrise311.jpg (150, 150, 3)
# > global features sunrise311.jpg (84,)
# > loaded sunrise312.jpg (150, 150, 3)
# > global features sunrise312.jpg (84,)
# > loaded sunrise313.jpg (150, 150, 3)
# > global features sunrise313.jpg (84,)
# > loaded sunrise314.jpg (150, 150, 3)
# > global features sunrise314.jpg (84,)
# > loaded sunrise315.jpg (150, 150, 3)
# > global features sunrise315.jpg (84,)
# > loaded sunrise316.jpg (150, 150, 3)
# > global features sunrise316.jpg (84,)
# > loaded sunrise317.jpg (150, 150, 3)
# > global features sunrise317.jpg (84,)
# > loaded sunrise318.jpg (150, 150, 3)
# > global features sunrise318.jpg (84,)
# > loaded sunrise319.jpg (150, 150, 3)
# > global features sunrise319.jpg (84,)
# > loaded sunrise32.jpg (150, 150, 3)
# > global features sunrise32.jpg (84,)
# > loaded sunrise320.jpg (150, 150, 3)
# > global features sunrise320.jpg (84,)
# > loaded sunrise321.jpg (150, 150, 3)
# > global features sunrise321.jpg (84,)
# > loaded sunrise322.jpg (150, 150, 3)
# > global features sunrise322.jpg (84,)
# > loaded sunrise323.jpg (150, 150, 3)
# > global features sunrise323.jpg (84,)
# > loaded sunrise324.jpg (150, 150, 3)
# > global features sunrise324.jpg (84,)
# > loaded sunrise325.jpg (150, 150, 3)
# > global features sunrise325.jpg (84,)
# > loaded sunrise326.jpg (150, 150, 3)
# > global features sunrise326.jpg (84,)
# > loaded sunrise327.jpg (150, 150, 3)
# > global features sunrise327.jpg (84,)
# > loaded sunrise328.jpg (150, 150, 3)
# > global features sunrise328.jpg (84,)
# > loaded sunrise329.jpg (150, 150, 3)
# > global features sunrise329.jpg (84,)
# > loaded sunrise33.jpg (150, 150, 3)
# > global features sunrise33.jpg (84,)
# > loaded sunrise330.jpg (150, 150, 3)
# > global features sunrise330.jpg (84,)
# > loaded sunrise331.jpg (150, 150, 3)
# > global features sunrise331.jpg (84,)
# > loaded sunrise332.jpg (150, 150, 3)
# > global features sunrise332.jpg (84,)
# > loaded sunrise333.jpg (150, 150, 3)
# > global features sunrise333.jpg (84,)
# > loaded sunrise334.jpg (150, 150, 3)
# > global features sunrise334.jpg (84,)
# > loaded sunrise335.jpg (150, 150, 3)
# > global features sunrise335.jpg (84,)
# > loaded sunrise336.jpg (150, 150, 3)
# > global features sunrise336.jpg (84,)
# > loaded sunrise337.jpg (150, 150, 3)
# > global features sunrise337.jpg (84,)
# > loaded sunrise338.jpg (150, 150, 3)
# > global features sunrise338.jpg (84,)
# > loaded sunrise339.jpg (150, 150, 3)
# > global features sunrise339.jpg (84,)
# > loaded sunrise34.jpg (150, 150, 3)
# > global features sunrise34.jpg (84,)
# > loaded sunrise340.jpg (150, 150, 3)
# > global features sunrise340.jpg (84,)
# > loaded sunrise341.jpg (150, 150, 3)
# > global features sunrise341.jpg (84,)
# > loaded sunrise342.jpg (150, 150, 3)
# > global features sunrise342.jpg (84,)
# > loaded sunrise343.jpg (150, 150, 3)
# > global features sunrise343.jpg (84,)
# > loaded sunrise344.jpg (150, 150, 3)
# > global features sunrise344.jpg (84,)
# > loaded sunrise345.jpg (150, 150, 3)
# > global features sunrise345.jpg (84,)
# > loaded sunrise346.jpg (150, 150, 3)
# > global features sunrise346.jpg (84,)
# > loaded sunrise347.jpg (150, 150, 3)
# > global features sunrise347.jpg (84,)
# > loaded sunrise348.jpg (150, 150, 3)
# > global features sunrise348.jpg (84,)
# > loaded sunrise349.jpg (150, 150, 3)
# > global features sunrise349.jpg (84,)
# > loaded sunrise35.jpg (150, 150, 3)
# > global features sunrise35.jpg (84,)
# > loaded sunrise350.jpg (150, 150, 3)
# > global features sunrise350.jpg (84,)
# > loaded sunrise351.jpg (150, 150, 3)
# > global features sunrise351.jpg (84,)
# > loaded sunrise352.jpg (150, 150, 3)
# > global features sunrise352.jpg (84,)
# > loaded sunrise353.jpg (150, 150, 3)
# > global features sunrise353.jpg (84,)
# > loaded sunrise354.jpg (150, 150, 3)
# > global features sunrise354.jpg (84,)
# > loaded sunrise355.jpg (150, 150, 3)
# > global features sunrise355.jpg (84,)
# > loaded sunrise356.jpg (150, 150, 3)
# > global features sunrise356.jpg (84,)
# > loaded sunrise357.jpg (150, 150, 3)
# > global features sunrise357.jpg (84,)
# > loaded sunrise36.jpg (150, 150, 3)
# > global features sunrise36.jpg (84,)
# > loaded sunrise37.jpg (150, 150, 3)
# > global features sunrise37.jpg (84,)
# > loaded sunrise38.jpg (150, 150, 3)
# > global features sunrise38.jpg (84,)
# > loaded sunrise39.jpg (150, 150, 3)
# > global features sunrise39.jpg (84,)
# > loaded sunrise4.jpg (150, 150, 3)
# > global features sunrise4.jpg (84,)
# > loaded sunrise40.jpg (150, 150, 3)
# > global features sunrise40.jpg (84,)
# > loaded sunrise41.jpg (150, 150, 3)
# > global features sunrise41.jpg (84,)
# > loaded sunrise42.jpg (150, 150, 3)
# > global features sunrise42.jpg (84,)
# > loaded sunrise43.jpg (150, 150, 3)
# > global features sunrise43.jpg (84,)
# > loaded sunrise44.jpg (150, 150, 3)
# > global features sunrise44.jpg (84,)
# > loaded sunrise45.jpg (150, 150, 3)
# > global features sunrise45.jpg (84,)
# > loaded sunrise46.jpg (150, 150, 3)
# > global features sunrise46.jpg (84,)
# > loaded sunrise47.jpg (150, 150, 3)
# > global features sunrise47.jpg (84,)
# > loaded sunrise48.jpg (150, 150, 3)
# > global features sunrise48.jpg (84,)
# > loaded sunrise49.jpg (150, 150, 3)
# > global features sunrise49.jpg (84,)
# > loaded sunrise5.jpg (150, 150, 3)
# > global features sunrise5.jpg (84,)
# > loaded sunrise50.jpg (150, 150, 3)
# > global features sunrise50.jpg (84,)
# > loaded sunrise51.jpg (150, 150, 3)
# > global features sunrise51.jpg (84,)
# > loaded sunrise52.jpg (150, 150, 3)
# > global features sunrise52.jpg (84,)
# > loaded sunrise53.jpg (150, 150, 3)
# > global features sunrise53.jpg (84,)
# > loaded sunrise54.jpg (150, 150, 3)
# > global features sunrise54.jpg (84,)
# > loaded sunrise55.jpg (150, 150, 3)
# > global features sunrise55.jpg (84,)
# > loaded sunrise56.jpg (150, 150, 3)
# > global features sunrise56.jpg (84,)
# > loaded sunrise57.jpg (150, 150, 3)
# > global features sunrise57.jpg (84,)
# > loaded sunrise58.jpg (150, 150, 3)
# > global features sunrise58.jpg (84,)
# > loaded sunrise59.jpg (150, 150, 3)
# > global features sunrise59.jpg (84,)
# > loaded sunrise6.jpg (150, 150, 3)
# > global features sunrise6.jpg (84,)
# > loaded sunrise60.jpg (150, 150, 3)
# > global features sunrise60.jpg (84,)
# > loaded sunrise61.jpg (150, 150, 3)
# > global features sunrise61.jpg (84,)
# > loaded sunrise62.jpg (150, 150, 3)
# > global features sunrise62.jpg (84,)
# > loaded sunrise63.jpg (150, 150, 3)
# > global features sunrise63.jpg (84,)
# > loaded sunrise64.jpg (150, 150, 3)
# > global features sunrise64.jpg (84,)
# > loaded sunrise65.jpg (150, 150, 3)
# > global features sunrise65.jpg (84,)
# > loaded sunrise66.jpg (150, 150, 3)
# > global features sunrise66.jpg (84,)
# > loaded sunrise67.jpg (150, 150, 3)
# > global features sunrise67.jpg (84,)
# > loaded sunrise68.jpg (150, 150, 3)
# > global features sunrise68.jpg (84,)
# > loaded sunrise69.jpg (150, 150, 3)
# > global features sunrise69.jpg (84,)
# > loaded sunrise7.jpg (150, 150, 3)
# > global features sunrise7.jpg (84,)
# > loaded sunrise70.jpg (150, 150, 3)
# > global features sunrise70.jpg (84,)
# > loaded sunrise71.jpg (150, 150, 3)
# > global features sunrise71.jpg (84,)
# > loaded sunrise72.jpg (150, 150, 3)
# > global features sunrise72.jpg (84,)
# > loaded sunrise73.jpg (150, 150, 3)
# > global features sunrise73.jpg (84,)
# > loaded sunrise74.jpg (150, 150, 3)
# > global features sunrise74.jpg (84,)
# > loaded sunrise75.jpg (150, 150, 3)
# > global features sunrise75.jpg (84,)
# > loaded sunrise76.jpg (150, 150, 3)
# > global features sunrise76.jpg (84,)
# > loaded sunrise77.jpg (150, 150, 3)
# > global features sunrise77.jpg (84,)
# > loaded sunrise78.jpg (150, 150, 3)
# > global features sunrise78.jpg (84,)
# > loaded sunrise79.jpg (150, 150, 3)
# > global features sunrise79.jpg (84,)
# > loaded sunrise8.jpg (150, 150, 3)
# > global features sunrise8.jpg (84,)
# > loaded sunrise80.jpg (150, 150, 3)
# > global features sunrise80.jpg (84,)
# > loaded sunrise81.jpg (150, 150, 3)
# > global features sunrise81.jpg (84,)
# > loaded sunrise82.jpg (150, 150, 3)
# > global features sunrise82.jpg (84,)
# > loaded sunrise83.jpg (150, 150, 3)
# > global features sunrise83.jpg (84,)
# > loaded sunrise84.jpg (150, 150, 3)
# > global features sunrise84.jpg (84,)
# > loaded sunrise85.jpg (150, 150, 3)
# > global features sunrise85.jpg (84,)
# > loaded sunrise86.jpg (150, 150, 3)
# > global features sunrise86.jpg (84,)
# > loaded sunrise87.jpg (150, 150, 3)
# > global features sunrise87.jpg (84,)
# > loaded sunrise88.jpg (150, 150, 3)
# > global features sunrise88.jpg (84,)
# > loaded sunrise89.jpeg (150, 150, 3)
# > global features sunrise89.jpeg (84,)
# > loaded sunrise9.jpg (150, 150, 3)
# > global features sunrise9.jpg (84,)
# > loaded sunrise90.jpg (150, 150, 3)
# > global features sunrise90.jpg (84,)
# > loaded sunrise91.jpg (150, 150, 3)
# > global features sunrise91.jpg (84,)
# > loaded sunrise92.jpg (150, 150, 3)
# > global features sunrise92.jpg (84,)
# > loaded sunrise93.jpg (150, 150, 3)
# > global features sunrise93.jpg (84,)
# > loaded sunrise94.jpg (150, 150, 3)
# > global features sunrise94.jpg (84,)
# > loaded sunrise95.jpg (150, 150, 3)
# > global features sunrise95.jpg (84,)
# > loaded sunrise96.jpg (150, 150, 3)
# > global features sunrise96.jpg (84,)
# > loaded sunrise97.jpg (150, 150, 3)
# > global features sunrise97.jpg (84,)
# > loaded sunrise98.jpg (150, 150, 3)
# > global features sunrise98.jpg (84,)
# > loaded sunrise99.jpg (150, 150, 3)
# > global features sunrise99.jpg (84,)
# X_train shape:  (1122, 84)
# y_train shape:  (1122,)

# %%
# normalize data (0,1)
t = MinMaxScaler()
t.fit(X_train_aux)
X_train_aux = t.transform(X_train_aux)

X_train_bal, X_test_bal, y_train_bal, y_test_bal = train_test_split(X_train_aux, y_train_aux, test_size=0.3, random_state=100)
print(f"Training target statistics: {Counter(y_train_bal)}")
print(f"Testing target statistics: {Counter(y_test_bal)}")

# Global variables
X_sample = len(X_train_bal)
X_input = len(X_train_bal[1])
X_class = len(np.unique(y_train_bal))

X_train = X_train_bal
y_train = y_train_bal
X_test = X_test_bal
y_test = y_test_bal
# Out:
# Training target statistics: Counter({3: 253, 0: 196, 2: 179, 1: 157})
# Testing target statistics: Counter({0: 104, 3: 104, 2: 72, 1: 57})

# %% [markdown]
# ## QDPSO

# %% [markdown]
# ### All training

# %%
y_qdpso = np.load('mcw_metric_113_100_1000_84_qdpso.npy')

x_qdpso = np.array(range(len(y_qdpso[0])))

for i in range(len(y_qdpso)):
    lab = "Training " + str(i+1)
    plt.plot(x_qdpso, y_qdpso[i], label = lab)
#plt.title("The Loss of QDPSO During Differents Training")
plt.ylabel("Errors")
plt.xlabel("Iterations")
plt.legend()
plt.yscale('log')
#plt.xscale('log')
plt.show()

# %%
qdpso_cost = []
for i in range(len(y_qdpso)):
    qdpso_cost.append(y_qdpso[i][len(y_qdpso[0]) - 1])

qdpso_cost = np.array(qdpso_cost)
mean_qdpso = np.mean(qdpso_cost)
std_qdpso = np.std(qdpso_cost)
worst_qdpso = np.max(qdpso_cost)
best_qdpso = np.min(qdpso_cost) 
print("Worst: ", worst_qdpso, " Mean: ", mean_qdpso, ' Best: ', best_qdpso, " Std: ", std_qdpso)
print("Best loss during the training in: ", (qdpso_cost.tolist()).index(best_qdpso) + 1)
# Out:
# Worst:  0.5491813603564984  Mean:  0.26442333923048145  Best:  0.09905046125660906  Std:  0.1491198755501935
# Best loss during the training in:  1

# %% [markdown]
# ### Best training

# %%
y_qdpso_best = y_qdpso[(qdpso_cost.tolist()).index(best_qdpso)]
x_qdpso_best = np.array(range(len(y_qdpso_best)))
plt.plot(x_qdpso_best, y_qdpso_best)
#plt.title("The Best Loss of QDPSO Durinng the Training")
plt.ylabel("Errors")
plt.xlabel("Iterations")
plt.yscale('log')
plt.show()

# %% [markdown]
# ### Confusion matrix

# %%
qdpso_model_load = np.load('mcw_gBest_113_100_1000_84_qdpso.npy')
nn_qdpso = perceptron(X_sample, X_input, X_class)
y_test_qdpso = np.argmax(nn_qdpso.forward(X_test, qdpso_model_load), axis=1)
cf_matrix_qdpso = confusion_matrix(y_test, y_test_qdpso)
print(cf_matrix_qdpso)
print("F1 score weighted: ", f1_score(y_test, y_test_qdpso, average='weighted'))
print("Recall score weighted: ", recall_score(y_test, y_test_qdpso, average='weighted'))
print("Precision score weighted: ", precision_score(y_test, y_test_qdpso, average='weighted'))
# Out:
# [[93  6  5  0]
#  [ 8 49  0  0]
#  [ 3  1 68  0]
#  [ 2  0  3 99]]
# F1 score weighted:  0.9173545989327957
# Recall score weighted:  0.9169139465875371
# Precision score weighted:  0.9185202838292191

# %%
#group_names = ['True Neg','False Pos','False Neg','True Pos']

group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix_qdpso.flatten()]

group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix_qdpso.flatten()/np.sum(cf_matrix_qdpso)]

labels = [f"{v1}\n{v2}" for v1, v2 in #\n{v3} , v3
          zip(group_counts, group_percentages)] #group_names,

labels = np.asarray(labels).reshape(4,4)

ax = sns.heatmap(cf_matrix_qdpso, annot=labels, fmt='', cmap='Blues')

#ax.set_title('Confusion Matrix of the Breast Dataset with QDPSO\n\n')
#ax.set_xlabel('\nPredicted Values')
#ax.set_ylabel('True Values ')

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['cloudy', 'rain', 'shine', 'sunrise'])
ax.yaxis.set_ticklabels(['cloudy', 'rain', 'shine', 'sunrise'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %% [markdown]
# ## PSO

# %% [markdown]
# ### All training

# %%
y_pso = np.load('mcw_metric_113_100_1000_84_pso.npy')
y_pso.shape

x_pso = np.array(range(len(y_pso[0])))

for i in range(len(y_pso)):
    lab = "Training " + str(i+1)
    plt.plot(x_pso, y_pso[i], label = lab)

#plt.title("The Loss of PSO During Differents Training")
plt.ylabel("Errors")
plt.xlabel("Iterations")
plt.legend()
#plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
pso_cost = []
for i in range(len(y_pso)):
    pso_cost.append(y_pso[i][len(y_pso[0]) - 1])
#print(y_qdpso[0])
#print(qdpso_cost)
pso_cost = np.array(pso_cost)
mean_pso = np.mean(pso_cost)
std_pso = np.std(pso_cost)
worst_pso = np.max(pso_cost)
best_pso = np.min(pso_cost) 
print("Worst: ", worst_pso, " Mean: ", mean_pso, " Best: ", best_pso,"Std: ", std_pso)
print("Best loss during the training in: ", (pso_cost.tolist()).index(best_pso) + 1)
# Out:
# Worst:  1.3667134382843882  Mean:  1.1113565792271942  Best:  0.32726211033645963 Std:  0.2888299585334106
# Best loss during the training in:  10

# %% [markdown]
# ### Best training

# %%
y_pso_best = y_pso[(pso_cost.tolist()).index(best_pso)]
x_pso_best = np.array(range(len(y_pso_best)))
plt.plot(x_pso_best, y_pso_best)
#plt.title("The Best Loss of PSO Durinng the Training")
plt.ylabel("Errors")
plt.xlabel("Iterations")
plt.yscale('log')
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
pso_model_load = np.load('mcw_gBest_113_100_1000_84_pso.npy')
nn_pso = perceptron_pso(X_sample, X_input, X_class)
y_test_pso = np.argmax(nn_pso.forward(X_test, pso_model_load), axis=1)
cf_matrix_pso = confusion_matrix(y_test, y_test_pso)
print(cf_matrix_pso)
print("F1 score weighted: ", f1_score(y_test, y_test_pso, average='weighted'))
print("Recall score weighted: ", recall_score(y_test, y_test_pso, average='weighted'))
print("Precision score weighted: ", precision_score(y_test, y_test_pso, average='weighted'))
# Out:
# [[79  8 13  4]
#  [11 45  1  0]
#  [ 3  1 68  0]
#  [ 2  2  5 95]]
# F1 score weighted:  0.8513231499949957
# Recall score weighted:  0.8516320474777448
# Precision score weighted:  0.8556724742487613

# %%
#group_names = ['True Neg','False Pos','False Neg','True Pos']

group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix_pso.flatten()]

group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix_pso.flatten()/np.sum(cf_matrix_pso)]

labels = [f"{v1}\n{v2}" for v1, v2 in #\n{v3} , v3
          zip(group_counts, group_percentages)] #group_names,

labels = np.asarray(labels).reshape(4,4)

ax = sns.heatmap(cf_matrix_pso, annot=labels, fmt='', cmap='Blues')

#ax.set_title('Confusion Matrix of the Breast Dataset with PSO\n\n')
#ax.set_xlabel('\nPredicted Values')
#ax.set_ylabel('True Values ')

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['cloudy', 'rain', 'shine', 'sunrise'])
ax.yaxis.set_ticklabels(['cloudy', 'rain', 'shine', 'sunrise'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %% [markdown]
# ## PSO_Bound

# %%
y_pso_bound = np.load('mcw_metric_113_100_1000_84_pso_bound.npy')
y_pso_bound.shape

x_pso_bound = np.array(range(len(y_pso_bound[0])))

for i in range(len(y_pso_bound)):
    lab = "Training " + str(i+1)
    plt.plot(x_pso_bound, y_pso_bound[i], label = lab)

#plt.title("The Loss of PSO_bound During Differents Training")
plt.ylabel("Errors")
plt.xlabel("Iterations")
plt.legend()
plt.yscale('log')
plt.show()

# %%
pso_bound_cost = []
for i in range(len(y_pso_bound)):
    pso_bound_cost.append(y_pso_bound[i][len(y_pso_bound[0]) - 1])

pso_bound_cost = np.array(pso_bound_cost)
mean_pso_bound = np.mean(pso_bound_cost)
std_pso_bound = np.std(pso_bound_cost)
worst_pso_bound = np.max(pso_bound_cost) 
best_pso_bound = np.min(pso_bound_cost)
print("Worst: ", worst_pso_bound, " Mean: ", mean_pso_bound," Best: ", best_pso_bound, " Std: ", std_pso_bound)
print("Best loss during the training in: ", (pso_bound_cost.tolist()).index(best_pso_bound) + 1)
# Out:
# Worst:  0.6133792274656876  Mean:  0.5287923362128464  Best:  0.4167230235454135  Std:  0.06074343109569904
# Best loss during the training in:  2

# %% [markdown]
# ### Best training

# %%
y_pso_bound_best = y_pso_bound[(pso_bound_cost.tolist()).index(best_pso_bound)]
x_pso_bound_best = np.array(range(len(y_pso_bound_best)))
plt.plot(x_pso_bound_best, y_pso_bound_best)
#plt.title("The Best Loss of PSO_bound Durinng the Training")
plt.ylabel("Errors")
plt.xlabel("Iterations")
plt.yscale('log')
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
pso_bound_model_load = np.load('mcw_gBest_113_100_1000_84_pso_bound.npy')
nn_pso_bound = perceptron_pso_bound(X_sample, X_input, X_class)
y_test_pso_bound = np.argmax(nn_pso_bound.forward(X_test, pso_model_load), axis=1)
cf_matrix_pso_bound = confusion_matrix(y_test, y_test_pso_bound)
print(cf_matrix_pso_bound)
print("F1 score weighted: ", f1_score(y_test, y_test_pso_bound, average='weighted'))
print("Recall score weighted: ", recall_score(y_test, y_test_pso_bound, average='weighted'))
print("Precision score weighted: ", precision_score(y_test, y_test_pso_bound, average='weighted'))
# Out:
# [[79  8 13  4]
#  [11 45  1  0]
#  [ 3  1 68  0]
#  [ 2  2  5 95]]
# F1 score weighted:  0.8513231499949957
# Recall score weighted:  0.8516320474777448
# Precision score weighted:  0.8556724742487613

# %%
#group_names = ['True Neg','False Pos','False Neg','True Pos']

group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix_pso_bound.flatten()]

group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix_pso_bound.flatten()/np.sum(cf_matrix_pso_bound)]

labels = [f"{v1}\n{v2}" for v1, v2 in #\n{v3} , v3
          zip(group_counts, group_percentages)] #group_names,

labels = np.asarray(labels).reshape(4,4)

ax = sns.heatmap(cf_matrix_pso_bound, annot=labels, fmt='', cmap='Blues')

#ax.set_title('Confusion Matrix of the Breast Dataset with PSO_bound\n\n')
#ax.set_xlabel('\nPredicted Values')
#ax.set_ylabel('True Values ')

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['cloudy', 'rain', 'shine', 'sunrise'])
ax.yaxis.set_ticklabels(['cloudy', 'rain', 'shine', 'sunrise'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %% [markdown]
# ## The best loss of the Metaheuristic-based optimizers

# %%
plt.plot(x_qdpso_best, y_qdpso_best, label = 'QDPSO')
plt.plot(x_pso_best, y_pso_best, label = 'PSO')
plt.plot(x_pso_bound_best, y_pso_bound_best, label = 'PSO_bound')
#plt.title("The Best Loss of the Metaheuristic-based Optimizers")
plt.ylabel("Errors")
plt.xlabel("Iterations")
plt.legend()
plt.yscale('log')
plt.show()

# %% [markdown]
# ## Adam

# %% [markdown]
# ### All training

# %%
with open ('mcw_metric_113_100_1000_84_adam', 'rb') as temp:
    y_adam = pk.load(temp)

x_adam = np.array(range(len(y_adam[0])))

for i in range (len(y_adam)):
    lab = "Training " + str(i+1)
    plt.plot(x_adam, y_adam[i], label = lab)

#plt.title("The Loss of Adam During Differents Training")
plt.ylabel("Errors")
plt.xlabel("Iterations")
plt.legend()
plt.xscale('log')
#plt.yscale('log')
plt.show()

# %%
adam_cost = []
for i in range(len(y_adam)):
    adam_cost.append(y_adam[i][len(y_adam[0]) - 1])

adam_cost = np.array(adam_cost)
mean_adam = np.mean(adam_cost)
std_adam = np.std(adam_cost)
worst_adam = np.max(adam_cost) 
best_adam = np.min(adam_cost)
print("Worst: ", worst_adam, " Mean: ", mean_adam, " Best: ", best_adam, " Std: ", std_adam)
print("Best loss during the training in: ", (adam_cost.tolist()).index(best_adam) + 1)
# Out:
# Worst:  0.03969299225992558  Mean:  0.038580688525563255  Best:  0.037188713721313424  Std:  0.0006971353902721887
# Best loss during the training in:  10

# %% [markdown]
# ### Best training

# %%
adam_loss_load = y_adam[(adam_cost.tolist()).index(best_adam)]
plt.plot(adam_loss_load)
#plt.title("The Best Loss of Adam Durinng the Training")
plt.ylabel("Errors")
plt.xlabel("Iterations")
plt.xscale('log')
plt.show()

# %% [markdown]
# ### Confussion Matrix

# %%
adam_model_load = jb.load('mcw_model_113_100_1000_84_adam.sav')
y_test_adam = adam_model_load.predict(X_test)
cf_matrix_adam = confusion_matrix(y_test, y_test_adam)
print(cf_matrix_adam)
print("F1 score weighted: ", f1_score(y_test, y_test_adam, average='weighted'))
print("Recall score weighted: ", recall_score(y_test, y_test_adam, average='weighted'))
print("Precision score weighted: ", precision_score(y_test, y_test_adam, average='weighted'))
# Out:
# [[92  8  4  0]
#  [ 7 50  0  0]
#  [ 4  1 66  1]
#  [ 3  1  5 95]]
# F1 score weighted:  0.899984627496285
# Recall score weighted:  0.8991097922848664
# Precision score weighted:  0.9021982718399493

# %%
#group_names = ['True Neg','False Pos','False Neg','True Pos']

group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix_adam.flatten()]

group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix_adam.flatten()/np.sum(cf_matrix_adam)]

labels = [f"{v1}\n{v2}" for v1, v2 in #\n{v3} , v3
          zip(group_counts, group_percentages)] #group_names,

labels = np.asarray(labels).reshape(4,4)

ax = sns.heatmap(cf_matrix_adam, annot=labels, fmt='', cmap='Blues')

#ax.set_title('Confusion Matrix of the Breast Dataset with Adam\n\n')
#ax.set_xlabel('\nPredicted Values')
#ax.set_ylabel('True Values ')

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['cloudy', 'rain', 'shine', 'sunrise'])
ax.yaxis.set_ticklabels(['cloudy', 'rain', 'shine', 'sunrise'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %% [markdown]
# ## L-BFGS

# %%
with open ('mcw_metric_113_100_1000_84_lbfgs', 'rb') as temp:
    y_lbfgs = pk.load(temp)

lbfgs_cost = np.array(y_lbfgs)
mean_lbfgs = np.mean(lbfgs_cost)
std_lbfgs = np.std(lbfgs_cost)
worst_lbfgs = np.max(lbfgs_cost) 
best_lbfgs = np.min(lbfgs_cost)
print("Worst: ", worst_lbfgs, "Mean: ", mean_lbfgs, ' Best: ', best_lbfgs, " Std: ", std_lbfgs)
print("Best loss during the training in: ", (lbfgs_cost.tolist()).index(best_lbfgs) + 1)
# Out:
# Worst:  0.003944354830097257 Mean:  0.002883662844949162  Best:  0.0024567240131998934  Std:  0.00043119303597996224
# Best loss during the training in:  10

# %% [markdown]
# ### Confusion Matrix

# %%
lbfgs_model_load = jb.load('mcw_model_113_100_1000_84_lbfgs.sav')
y_test_lbfgs = lbfgs_model_load.predict(X_test)
cf_matrix_lbfgs = confusion_matrix(y_test, y_test_lbfgs)
print(cf_matrix_lbfgs)
print("F1 score weighted: ", f1_score(y_test, y_test_lbfgs, average='weighted'))
print("Recall score weighted: ", recall_score(y_test, y_test_lbfgs, average='weighted'))
print("Precision score weighted: ", precision_score(y_test, y_test_lbfgs, average='weighted'))
# Out:
# [[95  7  2  0]
#  [ 6 50  1  0]
#  [ 5  0 66  1]
#  [ 2  0  4 98]]
# F1 score weighted:  0.9174070262892179
# Recall score weighted:  0.9169139465875371
# Precision score weighted:  0.9184773496793333

# %%
#group_names = ['True Neg','False Pos','False Neg','True Pos']

group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix_lbfgs.flatten()]

group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix_lbfgs.flatten()/np.sum(cf_matrix_lbfgs)]

labels = [f"{v1}\n{v2}" for v1, v2 in #\n{v3} , v3
          zip(group_counts, group_percentages)] #group_names,

labels = np.asarray(labels).reshape(4,4)

ax = sns.heatmap(cf_matrix_lbfgs, annot=labels, fmt='', cmap='Blues')

#ax.set_title('Confusion Matrix of the Breast Dataset with L-BFGS\n\n')
#ax.set_xlabel('\nPredicted Values')
#ax.set_ylabel('True Values ')

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['cloudy', 'rain', 'shine', 'sunrise'])
ax.yaxis.set_ticklabels(['cloudy', 'rain', 'shine', 'sunrise'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %% [markdown]
# ## SGD

# %%
with open ('mcw_metric_113_100_1000_84_sgd', 'rb') as temp:
    y_sgd = pk.load(temp)

x_sgd = np.array(range(len(y_sgd[0])))

for i in range (len(y_sgd)):
    lab = "Training " + str(i+1)
    plt.plot(x_sgd, y_sgd[i], label = lab)

#plt.title("The Loss of SGD During Differents Training")
plt.ylabel("Errors")
plt.xlabel("Iterations")
plt.legend()
plt.xscale('log')
plt.show()

# %%
sgd_cost = []
for i in range(len(y_sgd)):
    sgd_cost.append(y_sgd[i][len(y_sgd[0]) - 1])

sgd_cost = np.array(sgd_cost)
mean_sgd = np.mean(sgd_cost)
std_sgd = np.std(sgd_cost)
worst_sgd = np.max(sgd_cost) 
best_sgd = np.min(sgd_cost)
print(" Worst: ", worst_sgd, " Mean: ", mean_sgd, " Best: ", best_sgd, " Std: ", std_sgd)
print("Best loss during the training in: ", (sgd_cost.tolist()).index(best_sgd) + 1)
# Out:
#  Worst:  0.283507468118568  Mean:  0.2806432212174312  Best:  0.2780274713513208  Std:  0.0018532271331183103
# Best loss during the training in:  9

# %% [markdown]
# ### Best Training

# %%
sgd_loss_load = y_sgd[(sgd_cost.tolist()).index(best_sgd)]
plt.plot(sgd_loss_load)
#plt.title("The Best Loss of SGD Durinng the Training")
plt.ylabel("Errors")
plt.xlabel("Iterations")
plt.xscale('log')
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
sgd_model_load = jb.load('mcw_model_113_100_1000_84_sgd.sav')
y_test_sgd = sgd_model_load.predict(X_test)
cf_matrix_sgd = confusion_matrix(y_test, y_test_sgd)
print(cf_matrix_sgd)
print("F1 score weighted: ", f1_score(y_test, y_test_sgd, average='weighted'))
print("Recall score weighted: ", recall_score(y_test, y_test_sgd, average='weighted'))
print("Precision score weighted: ", precision_score(y_test, y_test_sgd, average='weighted'))
# Out:
# [[90  8  6  0]
#  [ 8 49  0  0]
#  [ 4  1 66  1]
#  [ 1  1  6 96]]
# F1 score weighted:  0.8940452184112115
# Recall score weighted:  0.8931750741839762
# Precision score weighted:  0.8963313989116848

# %%
#group_names = ['True Neg','False Pos','False Neg','True Pos']

group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix_sgd.flatten()]

group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix_sgd.flatten()/np.sum(cf_matrix_sgd)]

labels = [f"{v1}\n{v2}" for v1, v2 in #\n{v3} , v3
          zip(group_counts, group_percentages)] #group_names,

labels = np.asarray(labels).reshape(4,4)

ax = sns.heatmap(cf_matrix_sgd, annot=labels, fmt='', cmap='Blues')

#ax.set_title('Confusion Matrix of the Breast Dataset with SGD\n\n')
#ax.set_xlabel('\nPredicted Values')
#ax.set_ylabel('True Values ')

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['cloudy', 'rain', 'shine', 'sunrise'])
ax.yaxis.set_ticklabels(['cloudy', 'rain', 'shine', 'sunrise'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %% [markdown]
# ## The best loss of the Gradient-based optimizers

# %%
plt.plot(sgd_loss_load, label = 'SGD')
plt.plot(adam_loss_load, label = 'Adam')
#plt.title("The Best Loss of the Gadient-based Optimizers")
plt.ylabel("Errors")
plt.xlabel("Iterations")
plt.legend()
plt.xscale('log')
plt.show()

# %% [markdown]
# ## The best loss of the Gradient-based and Metaheuristic-based optimizers

# %%
plt.plot(x_qdpso_best, y_qdpso_best, label = 'QDPSO')
plt.plot(x_pso_best, y_pso_best, label = 'PSO')
plt.plot(x_pso_bound_best, y_pso_bound_best, label = 'PSO_bound')

plt.plot(sgd_loss_load, label = 'SGD')
plt.plot(adam_loss_load, label = 'Adam')
#plt.title("The Best Loss of the All Optimizers")
plt.ylabel("Errors")
plt.xlabel("Iterations")
plt.legend()
plt.yscale('log')
#plt.xscale('log')
plt.show()
